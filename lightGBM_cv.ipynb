# %%
import pandas as pd
import numpy as np
import datetime
from meteocalc import feels_like, Temp
import gc
from sklearn.preprocessing import LabelEncoder

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df


def import_data(file):
    """create a dataframe and optimize its memory usage"""
    df = pd.read_csv(file, parse_dates=True, keep_date_col=True)
    df = reduce_mem_usage(df)
    return df

# %%
train_df = import_data('train.csv')
building_df = import_data('building_metadata.csv')
weather_df = import_data('weather_train.csv')
# Out:
# Memory usage of dataframe is 616.95 MB
# Memory usage after optimization is: 173.90 MB
# Decreased by 71.8%
# Memory usage of dataframe is 0.07 MB
# Memory usage after optimization is: 0.02 MB
# Decreased by 73.8%
# Memory usage of dataframe is 9.60 MB
# Memory usage after optimization is: 2.65 MB
# Decreased by 72.4%

# %%
train_df = train_df [ train_df['building_id'] != 1099 ]
train_df['timestamp'] = pd.to_datetime(train_df['timestamp'])
train_df = train_df.query('not (building_id <= 104 & meter == 0 & timestamp <= "2016-05-20")')

# %%
train_df.head()
# Out:
#      building_id  meter  timestamp  meter_reading
# 103          105      0 2016-01-01      23.303600
# 104          106      0 2016-01-01       0.374600
# 105          106      3 2016-01-01       0.000000
# 106          107      0 2016-01-01     175.184006
# 107          108      0 2016-01-01      91.265297

# %%
def fill_weather_dataset(weather_df):
    
    weather_df["datetime"] = pd.to_datetime(weather_df["timestamp"])
    weather_df["day"] = weather_df["datetime"].dt.day
    weather_df["week"] = weather_df["datetime"].dt.week
    weather_df["month"] = weather_df["datetime"].dt.month
    weather_df = weather_df.set_index(['site_id','month'])
    
    return weather_df
    
weather_df = fill_weather_dataset(weather_df)

# %%
weather_df.head()
# Out:
#                          timestamp  air_temperature  cloud_coverage  \
# site_id month
# 0       1      2016-01-01 00:00:00        25.000000             6.0
#         1      2016-01-01 01:00:00        24.406250             NaN
#         1      2016-01-01 02:00:00        22.796875             2.0
#         1      2016-01-01 03:00:00        21.093750             2.0
#         1      2016-01-01 04:00:00        20.000000             2.0
#
#                dew_temperature  precip_depth_1_hr  sea_level_pressure  \
# site_id month
# 0       1             20.00000                NaN              1019.5
#         1             21.09375               -1.0              1020.0
#         1             21.09375                0.0              1020.0
#         1             20.59375                0.0              1020.0
#         1             20.00000               -1.0              1020.0
#
#                wind_direction  wind_speed            datetime  day  week
# site_id month
# 0       1                 0.0    0.000000 2016-01-01 00:00:00    1    53
#         1                70.0    1.500000 2016-01-01 01:00:00    1    53
#         1                 0.0    0.000000 2016-01-01 02:00:00    1    53
#         1                 0.0    0.000000 2016-01-01 03:00:00    1    53
#         1               250.0    2.599609 2016-01-01 04:00:00    1    53

# %%
percip = weather_df.groupby(['site_id','month'])[['precip_depth_1_hr']].mean()
cloud = weather_df.groupby(['site_id','month'])[['cloud_coverage']].mean()
airtemp = weather_df.groupby(['site_id','month'])[['air_temperature']].mean()
dewtemp = weather_df.groupby(['site_id','month'])[['dew_temperature']].mean()
sealevelp = weather_df.groupby(['site_id','month'])[['sea_level_pressure']].mean()
windd = weather_df.groupby(['site_id','month'])[['wind_direction']].mean()
winds = weather_df.groupby(['site_id','month'])[['wind_speed']].mean()

# %%
pd.set_option('display.max_rows', None)
# percip
# cloud
# airtemp
# dewtemp
# sealevelp
# windd
# winds

# %%
#for i in range(12):
#    percip.loc[(1,i+1)] = percip.loc[(7,i+1)]
#    percip.loc[(5,i+1)] = percip.loc[(7,i+1)]
#    percip.loc[(12,i+1)] = percip.loc[(7,i+1)]
    
#    cloud.loc[(7,i+1)] = cloud.loc[(5,i+1)]
#    cloud.loc[(11,i+1)] = cloud.loc[(5,i+1)]
    
#    sealevelp.loc[(5,i+1)] = sealevelp.loc[(7,i+1)]

# %%
weather_info = percip.join(cloud)
weather_info = weather_info.join(airtemp)
weather_info = weather_info.join(dewtemp)
weather_info = weather_info.join(sealevelp)
weather_info = weather_info.join(windd)
weather_info = weather_info.join(winds)
weather_info.head()
# Out:
#                precip_depth_1_hr  cloud_coverage  air_temperature  \
# site_id month
# 0       1               1.796875        3.667969        14.710938
#         2               0.593262        2.312500        16.140625
#         3               1.740234        3.265625        21.265625
#         4               0.197266        3.027344        22.437500
#         5               1.214844        2.765625        24.734375
#
#                dew_temperature  sea_level_pressure  wind_direction  wind_speed
# site_id month
# 0       1             9.210938              1018.0         196.750    3.642578
#         2             8.867188              1020.0         198.000    4.054688
#         3            14.429688              1018.5         174.500    3.632812
#         4            14.593750              1017.5         142.875    3.759766
#         5            17.234375              1016.0         157.375    3.220703

# %%
weather_df.update(weather_info,overwrite=False)
weather_df = weather_df.reset_index()
weather_df = weather_df.drop(['datetime','day','week','month'],axis=1)
weather_df.head()
# Out:
#    site_id            timestamp  air_temperature  cloud_coverage  \
# 0        0  2016-01-01 00:00:00        25.000000        6.000000
# 1        0  2016-01-01 01:00:00        24.406250        3.667969
# 2        0  2016-01-01 02:00:00        22.796875        2.000000
# 3        0  2016-01-01 03:00:00        21.093750        2.000000
# 4        0  2016-01-01 04:00:00        20.000000        2.000000
#
#    dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  \
# 0         20.00000           1.796875              1019.5             0.0
# 1         21.09375          -1.000000              1020.0            70.0
# 2         21.09375           0.000000              1020.0             0.0
# 3         20.59375           0.000000              1020.0             0.0
# 4         20.00000          -1.000000              1020.0           250.0
#
#    wind_speed
# 0    0.000000
# 1    1.500000
# 2    0.000000
# 3    0.000000
# 4    2.599609

# %%
def get_meteorological_features(data):
    
    def calculate_rh(df):
        df['relative_humidity'] = 100 * (np.exp((17.625 * df['dew_temperature']) / (243.04 + df['dew_temperature'])) / np.exp((17.625 * df['air_temperature'])/(243.04 + df['air_temperature'])))
    def calculate_fl(df):
        flike_final = []
        flike = []
        # calculate Feels Like temperature
        for i in range(len(df)):
            at = df['air_temperature'][i]
            rh = df['relative_humidity'][i]
            ws = df['wind_speed'][i]
            flike.append(feels_like(Temp(at, unit = 'C'), rh, ws))
        for i in range(len(flike)):
            flike_final.append(flike[i].f)
        df['feels_like'] = flike_final
        del flike_final, flike, at, rh, ws
    calculate_rh(data)
    calculate_fl(data)
    
    return data

# %%
weather_df = get_meteorological_features(weather_df)
weather_df.head()
# Out:
#    site_id            timestamp  air_temperature  cloud_coverage  \
# 0        0  2016-01-01 00:00:00        25.000000        6.000000
# 1        0  2016-01-01 01:00:00        24.406250        3.667969
# 2        0  2016-01-01 02:00:00        22.796875        2.000000
# 3        0  2016-01-01 03:00:00        21.093750        2.000000
# 4        0  2016-01-01 04:00:00        20.000000        2.000000
#
#    dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  \
# 0         20.00000           1.796875              1019.5             0.0
# 1         21.09375          -1.000000              1020.0            70.0
# 2         21.09375           0.000000              1020.0             0.0
# 3         20.59375           0.000000              1020.0             0.0
# 4         20.00000          -1.000000              1020.0           250.0
#
#    wind_speed  relative_humidity  feels_like
# 0    0.000000            73.8125   77.000000
# 1    1.500000            81.8750   75.931250
# 2    0.000000            90.1875   73.034375
# 3    0.000000            97.0000   69.968750
# 4    2.599609           100.0000   68.000000

# %%
def features_engineering(df):
    
    # Sort by timestamp
    df.sort_values("timestamp")
    df.reset_index(drop=True)
    
    # Add more features
    df["timestamp"] = pd.to_datetime(df["timestamp"],format="%Y-%m-%d %H:%M:%S")
    df["hour"] = df["timestamp"].dt.hour
    df["dayofweek"] = df["timestamp"].dt.dayofweek
    
    df['month'] = df['timestamp'].dt.month
    df['month'].replace((1, 2, 3, 4), 1, inplace = True)
    df['month'].replace((5, 6, 7, 8), 2, inplace = True)
    df['month'].replace((9, 10, 11, 12), 3, inplace = True)
  
    df['square_feet'] =  np.log1p(df['square_feet'])
    
    # Remove Unused Columns
    drop = ["timestamp"]
    df = df.drop(drop, axis=1)
    gc.collect()
    
    # Encode Categorical Data
    le = LabelEncoder()
    df["primary_use"] = le.fit_transform(df["primary_use"])
    
    return df

# %%
# weather_df.head()
# train_df.head()

# %%
weather_df['timestamp'] = pd.to_datetime(weather_df['timestamp'], format="%Y-%m-%d %H:%M:%S")

# merge data
train_df = train_df.merge(building_df, left_on='building_id',right_on='building_id',how='left')
train_df = train_df.merge(weather_df,how='left',left_on=['site_id','timestamp'],right_on=['site_id','timestamp'])
del weather_df
gc.collect()
# Out:
# 89

# %%
# feature engineering
train_df = features_engineering(train_df)

# transform target variable
train_df['square_feet'] = np.log1p(train_df["square_feet"])

# %%
train_df = train_df.drop(['month'], axis=1)
train_df = train_df.drop(['sea_level_pressure','wind_direction','wind_speed','year_built','floor_count'], axis=1)
train_df['meter_reading'] = np.log1p(train_df['meter_reading'])
train_df.head()
# Out:
#    building_id  meter  meter_reading  site_id  primary_use  square_feet  \
# 0          105      0       3.190624        1            0     2.470823
# 1          106      0       0.318163        1            0     2.260670
# 2          106      3       0.000000        1            0     2.260670
# 3          107      0       5.171529        1            0     2.524764
# 4          108      0       4.524668        1            0     2.510359
#
#    air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  \
# 0         3.800781             0.0         2.400391                NaN
# 1         3.800781             0.0         2.400391                NaN
# 2         3.800781             0.0         2.400391                NaN
# 3         3.800781             0.0         2.400391                NaN
# 4         3.800781             0.0         2.400391                NaN
#
#    relative_humidity  feels_like  hour  dayofweek
# 0             90.625   36.935821     0          4
# 1             90.625   36.935821     0          4
# 2             90.625   36.935821     0          4
# 3             90.625   36.935821     0          4
# 4             90.625   36.935821     0          4

# %% [markdown]
# ## lightGBM randomsearchCV

# %%
from sklearn.model_selection import KFold
import lightgbm as lgb
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform

# %%
categorical_features = ["building_id", "site_id", "meter", "primary_use",'dayofweek','hour']

mdl =  lgb.LGBMRegressor(boosting_type= 'gbdt',
          objective = 'regression',
          n_jobs = -1, # Updated from 'nthread'
          silent = 0
          #feature_fraction= 0.85,
          #reg_lambda= 2,
          #max_depth = params['max_depth'],
          #max_bin = params['max_bin'],
          #subsample_for_bin = params['subsample_for_bin'],
          #subsample = params['subsample'],
          #subsample_freq = params['subsample_freq'],
          #min_split_gain = params['min_split_gain'],
          #min_child_weight = params['min_child_weight'],
          #min_child_samples = params['min_child_samples'],
          #scale_pos_weight = params['scale_pos_weight'] 
          )

# %%
param_test ={
              "num_leaves": sp_randint(6,1280),
              "learning_rate": [0.01, 0.05, 0.1],
              "feature_fraction": [0.4,0.5,0.6,0.7,0.8,0.9,1],
              "reg_lambda": [0,0.1,1,2,7,10],
              "reg_alpha": [0,0.1,1,2,7,10],
              "subsample": [0.6,0.7,0.8,0.9,1],
              "min_child_samples": sp_randint(100, 1000)
            }

# %%
def rmsle(y_true, y_pred):
    return np.sqrt(np.mean(np.power(np.log1p(y_pred) - np.log1p(y_true), 2)))

from sklearn.metrics.scorer import make_scorer

my_scorer = make_scorer(rmsle, greater_is_better=False)

# %%
#This parameter defines the number of HP points to be tested
n_HP_points_to_test = 100


#n_estimators is set to a "large value". The actual number of trees build will depend on early stopping and 5000 define only the absolute maximum
#clf = lgb.LGBMClassifier(max_depth=-1, random_state=314, silent=True, metric='None', n_jobs=4, n_estimators=5000)
gs = RandomizedSearchCV(
    estimator=mdl, param_distributions=param_test, 
    n_iter=n_HP_points_to_test,
    cv=3,
    scoring = my_scorer,
    refit=True,
    random_state=314,
    verbose=200)

# %%
#del train_df,weather_df, building_df

# %%
X_train = train_df.drop(['meter_reading'], axis=1)
y_train = train_df['meter_reading']

gs.fit(X_train, y_train, categorical_feature = categorical_features)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] feature_fraction=0.4, learning_rate=0.05, min_child_samples=813, num_leaves=860, reg_alpha=1, reg_lambda=0, subsample=0.8
# C:\Users\legle\Anaconda3\lib\site-packages\lightgbm\basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['building_id', 'dayofweek', 'hour', 'meter', 'primary_use', 'site_id']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# [CV]  feature_fraction=0.4, learning_rate=0.05, min_child_samples=813, num_leaves=860, reg_alpha=1, reg_lambda=0, subsample=0.8, score=-0.401, total= 2.6min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.6min remaining:    0.0s
# [CV] feature_fraction=0.4, learning_rate=0.05, min_child_samples=813, num_leaves=860, reg_alpha=1, reg_lambda=0, subsample=0.8
# C:\Users\legle\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log1p
# [CV]  feature_fraction=0.4, learning_rate=0.05, min_child_samples=813, num_leaves=860, reg_alpha=1, reg_lambda=0, subsample=0.8, score=-0.388, total= 2.7min
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  5.3min remaining:    0.0s
# [CV] feature_fraction=0.4, learning_rate=0.05, min_child_samples=813, num_leaves=860, reg_alpha=1, reg_lambda=0, subsample=0.8
# [CV]  feature_fraction=0.4, learning_rate=0.05, min_child_samples=813, num_leaves=860, reg_alpha=1, reg_lambda=0, subsample=0.8, score=-0.394, total= 2.9min
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  8.2min remaining:    0.0s
# [CV] feature_fraction=0.6, learning_rate=0.01, min_child_samples=954, num_leaves=77, reg_alpha=0, reg_lambda=2, subsample=1
# [CV]  feature_fraction=0.6, learning_rate=0.01, min_child_samples=954, num_leaves=77, reg_alpha=0, reg_lambda=2, subsample=1, score=-0.509, total= 1.8min
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  9.9min remaining:    0.0s
# [CV] feature_fraction=0.6, learning_rate=0.01, min_child_samples=954, num_leaves=77, reg_alpha=0, reg_lambda=2, subsample=1
# [CV]  feature_fraction=0.6, learning_rate=0.01, min_child_samples=954, num_leaves=77, reg_alpha=0, reg_lambda=2, subsample=1, score=-0.485, total= 1.7min
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed: 11.6min remaining:    0.0s
# [CV] feature_fraction=0.6, learning_rate=0.01, min_child_samples=954, num_leaves=77, reg_alpha=0, reg_lambda=2, subsample=1
# [CV]  feature_fraction=0.6, learning_rate=0.01, min_child_samples=954, num_leaves=77, reg_alpha=0, reg_lambda=2, subsample=1, score=-0.495, total= 1.7min
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed: 13.3min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.01, min_child_samples=104, num_leaves=934, reg_alpha=2, reg_lambda=7, subsample=0.6
# [CV]  feature_fraction=1, learning_rate=0.01, min_child_samples=104, num_leaves=934, reg_alpha=2, reg_lambda=7, subsample=0.6, score=-0.445, total= 4.4min
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed: 17.7min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.01, min_child_samples=104, num_leaves=934, reg_alpha=2, reg_lambda=7, subsample=0.6
# [CV]  feature_fraction=1, learning_rate=0.01, min_child_samples=104, num_leaves=934, reg_alpha=2, reg_lambda=7, subsample=0.6, score=-0.428, total= 5.1min
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 22.9min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.01, min_child_samples=104, num_leaves=934, reg_alpha=2, reg_lambda=7, subsample=0.6
# [CV]  feature_fraction=1, learning_rate=0.01, min_child_samples=104, num_leaves=934, reg_alpha=2, reg_lambda=7, subsample=0.6, score=-0.436, total= 5.1min
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 27.9min remaining:    0.0s
# [CV] feature_fraction=0.4, learning_rate=0.01, min_child_samples=211, num_leaves=835, reg_alpha=10, reg_lambda=1, subsample=0.9
# [CV]  feature_fraction=0.4, learning_rate=0.01, min_child_samples=211, num_leaves=835, reg_alpha=10, reg_lambda=1, subsample=0.9, score=-0.508, total= 3.1min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed: 31.0min remaining:    0.0s
# [CV] feature_fraction=0.4, learning_rate=0.01, min_child_samples=211, num_leaves=835, reg_alpha=10, reg_lambda=1, subsample=0.9
# [CV]  feature_fraction=0.4, learning_rate=0.01, min_child_samples=211, num_leaves=835, reg_alpha=10, reg_lambda=1, subsample=0.9, score=-0.487, total= 3.4min
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed: 34.4min remaining:    0.0s
# [CV] feature_fraction=0.4, learning_rate=0.01, min_child_samples=211, num_leaves=835, reg_alpha=10, reg_lambda=1, subsample=0.9
# [CV]  feature_fraction=0.4, learning_rate=0.01, min_child_samples=211, num_leaves=835, reg_alpha=10, reg_lambda=1, subsample=0.9, score=-0.496, total= 3.3min
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 37.7min remaining:    0.0s
# [CV] feature_fraction=0.7, learning_rate=0.01, min_child_samples=748, num_leaves=233, reg_alpha=1, reg_lambda=0.1, subsample=0.6
# [CV]  feature_fraction=0.7, learning_rate=0.01, min_child_samples=748, num_leaves=233, reg_alpha=1, reg_lambda=0.1, subsample=0.6, score=-0.487, total= 2.7min
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 40.4min remaining:    0.0s
# [CV] feature_fraction=0.7, learning_rate=0.01, min_child_samples=748, num_leaves=233, reg_alpha=1, reg_lambda=0.1, subsample=0.6
# [CV]  feature_fraction=0.7, learning_rate=0.01, min_child_samples=748, num_leaves=233, reg_alpha=1, reg_lambda=0.1, subsample=0.6, score=-0.466, total= 2.7min
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 43.1min remaining:    0.0s
# [CV] feature_fraction=0.7, learning_rate=0.01, min_child_samples=748, num_leaves=233, reg_alpha=1, reg_lambda=0.1, subsample=0.6
# [CV]  feature_fraction=0.7, learning_rate=0.01, min_child_samples=748, num_leaves=233, reg_alpha=1, reg_lambda=0.1, subsample=0.6, score=-0.475, total= 2.6min
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 45.7min remaining:    0.0s
# [CV] feature_fraction=0.9, learning_rate=0.05, min_child_samples=289, num_leaves=1020, reg_alpha=10, reg_lambda=2, subsample=0.9
# [CV]  feature_fraction=0.9, learning_rate=0.05, min_child_samples=289, num_leaves=1020, reg_alpha=10, reg_lambda=2, subsample=0.9, score=-0.364, total= 4.3min
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed: 50.0min remaining:    0.0s
# [CV] feature_fraction=0.9, learning_rate=0.05, min_child_samples=289, num_leaves=1020, reg_alpha=10, reg_lambda=2, subsample=0.9
# [CV]  feature_fraction=0.9, learning_rate=0.05, min_child_samples=289, num_leaves=1020, reg_alpha=10, reg_lambda=2, subsample=0.9, score=-0.341, total= 3.8min
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed: 53.7min remaining:    0.0s
# [CV] feature_fraction=0.9, learning_rate=0.05, min_child_samples=289, num_leaves=1020, reg_alpha=10, reg_lambda=2, subsample=0.9
# [CV]  feature_fraction=0.9, learning_rate=0.05, min_child_samples=289, num_leaves=1020, reg_alpha=10, reg_lambda=2, subsample=0.9, score=-0.367, total= 3.7min
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 57.4min remaining:    0.0s
# [CV] feature_fraction=0.5, learning_rate=0.05, min_child_samples=488, num_leaves=143, reg_alpha=2, reg_lambda=1, subsample=0.6
# [CV]  feature_fraction=0.5, learning_rate=0.05, min_child_samples=488, num_leaves=143, reg_alpha=2, reg_lambda=1, subsample=0.6, score=-0.399, total= 1.8min
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed: 59.3min remaining:    0.0s
# [CV] feature_fraction=0.5, learning_rate=0.05, min_child_samples=488, num_leaves=143, reg_alpha=2, reg_lambda=1, subsample=0.6
# [CV]  feature_fraction=0.5, learning_rate=0.05, min_child_samples=488, num_leaves=143, reg_alpha=2, reg_lambda=1, subsample=0.6, score=-0.381, total= 2.1min
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 61.3min remaining:    0.0s
# [CV] feature_fraction=0.5, learning_rate=0.05, min_child_samples=488, num_leaves=143, reg_alpha=2, reg_lambda=1, subsample=0.6
# [CV]  feature_fraction=0.5, learning_rate=0.05, min_child_samples=488, num_leaves=143, reg_alpha=2, reg_lambda=1, subsample=0.6, score=-0.385, total= 2.2min
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed: 63.5min remaining:    0.0s
# [CV] feature_fraction=0.9, learning_rate=0.1, min_child_samples=224, num_leaves=885, reg_alpha=1, reg_lambda=0, subsample=0.6
# [CV]  feature_fraction=0.9, learning_rate=0.1, min_child_samples=224, num_leaves=885, reg_alpha=1, reg_lambda=0, subsample=0.6, score=-0.366, total= 3.3min
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 66.8min remaining:    0.0s
# [CV] feature_fraction=0.9, learning_rate=0.1, min_child_samples=224, num_leaves=885, reg_alpha=1, reg_lambda=0, subsample=0.6
# [CV]  feature_fraction=0.9, learning_rate=0.1, min_child_samples=224, num_leaves=885, reg_alpha=1, reg_lambda=0, subsample=0.6, score=-0.339, total= 3.2min
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed: 70.0min remaining:    0.0s
# [CV] feature_fraction=0.9, learning_rate=0.1, min_child_samples=224, num_leaves=885, reg_alpha=1, reg_lambda=0, subsample=0.6
# [CV]  feature_fraction=0.9, learning_rate=0.1, min_child_samples=224, num_leaves=885, reg_alpha=1, reg_lambda=0, subsample=0.6, score=-0.370, total= 3.3min
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed: 73.3min remaining:    0.0s
# [CV] feature_fraction=0.6, learning_rate=0.05, min_child_samples=634, num_leaves=256, reg_alpha=1, reg_lambda=0.1, subsample=0.8
# [CV]  feature_fraction=0.6, learning_rate=0.05, min_child_samples=634, num_leaves=256, reg_alpha=1, reg_lambda=0.1, subsample=0.8, score=-0.382, total= 2.0min
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed: 75.4min remaining:    0.0s
# [CV] feature_fraction=0.6, learning_rate=0.05, min_child_samples=634, num_leaves=256, reg_alpha=1, reg_lambda=0.1, subsample=0.8
# [CV]  feature_fraction=0.6, learning_rate=0.05, min_child_samples=634, num_leaves=256, reg_alpha=1, reg_lambda=0.1, subsample=0.8, score=-0.365, total= 2.5min
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed: 77.9min remaining:    0.0s
# [CV] feature_fraction=0.6, learning_rate=0.05, min_child_samples=634, num_leaves=256, reg_alpha=1, reg_lambda=0.1, subsample=0.8
# [CV]  feature_fraction=0.6, learning_rate=0.05, min_child_samples=634, num_leaves=256, reg_alpha=1, reg_lambda=0.1, subsample=0.8, score=-0.375, total= 2.9min
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed: 80.8min remaining:    0.0s
# [CV] feature_fraction=0.7, learning_rate=0.05, min_child_samples=801, num_leaves=1074, reg_alpha=0, reg_lambda=1, subsample=0.7
# [CV]  feature_fraction=0.7, learning_rate=0.05, min_child_samples=801, num_leaves=1074, reg_alpha=0, reg_lambda=1, subsample=0.7, score=-0.366, total= 4.4min
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed: 85.2min remaining:    0.0s
# [CV] feature_fraction=0.7, learning_rate=0.05, min_child_samples=801, num_leaves=1074, reg_alpha=0, reg_lambda=1, subsample=0.7
# [CV]  feature_fraction=0.7, learning_rate=0.05, min_child_samples=801, num_leaves=1074, reg_alpha=0, reg_lambda=1, subsample=0.7, score=-0.346, total= 4.3min
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed: 89.5min remaining:    0.0s
# [CV] feature_fraction=0.7, learning_rate=0.05, min_child_samples=801, num_leaves=1074, reg_alpha=0, reg_lambda=1, subsample=0.7
# [CV]  feature_fraction=0.7, learning_rate=0.05, min_child_samples=801, num_leaves=1074, reg_alpha=0, reg_lambda=1, subsample=0.7, score=-0.367, total= 4.0min
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed: 93.5min remaining:    0.0s
# [CV] feature_fraction=0.5, learning_rate=0.01, min_child_samples=456, num_leaves=609, reg_alpha=2, reg_lambda=10, subsample=0.9
# [CV]  feature_fraction=0.5, learning_rate=0.01, min_child_samples=456, num_leaves=609, reg_alpha=2, reg_lambda=10, subsample=0.9, score=-0.488, total= 3.3min
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed: 96.8min remaining:    0.0s
# [CV] feature_fraction=0.5, learning_rate=0.01, min_child_samples=456, num_leaves=609, reg_alpha=2, reg_lambda=10, subsample=0.9
# [CV]  feature_fraction=0.5, learning_rate=0.01, min_child_samples=456, num_leaves=609, reg_alpha=2, reg_lambda=10, subsample=0.9, score=-0.469, total= 2.8min
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed: 99.7min remaining:    0.0s
# [CV] feature_fraction=0.5, learning_rate=0.01, min_child_samples=456, num_leaves=609, reg_alpha=2, reg_lambda=10, subsample=0.9
# [CV]  feature_fraction=0.5, learning_rate=0.01, min_child_samples=456, num_leaves=609, reg_alpha=2, reg_lambda=10, subsample=0.9, score=-0.478, total= 2.9min
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed: 102.6min remaining:    0.0s
# [CV] feature_fraction=0.6, learning_rate=0.05, min_child_samples=820, num_leaves=329, reg_alpha=1, reg_lambda=0, subsample=0.9
# [CV]  feature_fraction=0.6, learning_rate=0.05, min_child_samples=820, num_leaves=329, reg_alpha=1, reg_lambda=0, subsample=0.9, score=-0.378, total= 2.5min
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed: 105.1min remaining:    0.0s
# [CV] feature_fraction=0.6, learning_rate=0.05, min_child_samples=820, num_leaves=329, reg_alpha=1, reg_lambda=0, subsample=0.9
# [CV]  feature_fraction=0.6, learning_rate=0.05, min_child_samples=820, num_leaves=329, reg_alpha=1, reg_lambda=0, subsample=0.9, score=-0.362, total= 2.2min
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed: 107.3min remaining:    0.0s
# [CV] feature_fraction=0.6, learning_rate=0.05, min_child_samples=820, num_leaves=329, reg_alpha=1, reg_lambda=0, subsample=0.9
# [CV]  feature_fraction=0.6, learning_rate=0.05, min_child_samples=820, num_leaves=329, reg_alpha=1, reg_lambda=0, subsample=0.9, score=-0.373, total= 2.7min
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed: 110.0min remaining:    0.0s
# [CV] feature_fraction=0.5, learning_rate=0.05, min_child_samples=650, num_leaves=859, reg_alpha=10, reg_lambda=2, subsample=0.9
# [CV]  feature_fraction=0.5, learning_rate=0.05, min_child_samples=650, num_leaves=859, reg_alpha=10, reg_lambda=2, subsample=0.9, score=-0.375, total= 3.3min
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed: 113.3min remaining:    0.0s
# [CV] feature_fraction=0.5, learning_rate=0.05, min_child_samples=650, num_leaves=859, reg_alpha=10, reg_lambda=2, subsample=0.9
# [CV]  feature_fraction=0.5, learning_rate=0.05, min_child_samples=650, num_leaves=859, reg_alpha=10, reg_lambda=2, subsample=0.9, score=-0.360, total= 3.1min
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed: 116.4min remaining:    0.0s
# [CV] feature_fraction=0.5, learning_rate=0.05, min_child_samples=650, num_leaves=859, reg_alpha=10, reg_lambda=2, subsample=0.9
# [CV]  feature_fraction=0.5, learning_rate=0.05, min_child_samples=650, num_leaves=859, reg_alpha=10, reg_lambda=2, subsample=0.9, score=-0.373, total= 3.2min
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed: 119.6min remaining:    0.0s
# [CV] feature_fraction=0.4, learning_rate=0.01, min_child_samples=404, num_leaves=263, reg_alpha=0.1, reg_lambda=7, subsample=1
# [CV]  feature_fraction=0.4, learning_rate=0.01, min_child_samples=404, num_leaves=263, reg_alpha=0.1, reg_lambda=7, subsample=1, score=-0.515, total= 2.3min
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed: 121.9min remaining:    0.0s
# [CV] feature_fraction=0.4, learning_rate=0.01, min_child_samples=404, num_leaves=263, reg_alpha=0.1, reg_lambda=7, subsample=1
# [CV]  feature_fraction=0.4, learning_rate=0.01, min_child_samples=404, num_leaves=263, reg_alpha=0.1, reg_lambda=7, subsample=1, score=-0.494, total= 2.6min
# [Parallel(n_jobs=1)]: Done  41 out of  41 | elapsed: 124.4min remaining:    0.0s
# [CV] feature_fraction=0.4, learning_rate=0.01, min_child_samples=404, num_leaves=263, reg_alpha=0.1, reg_lambda=7, subsample=1
# [CV]  feature_fraction=0.4, learning_rate=0.01, min_child_samples=404, num_leaves=263, reg_alpha=0.1, reg_lambda=7, subsample=1, score=-0.503, total= 2.6min
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed: 127.0min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.05, min_child_samples=651, num_leaves=473, reg_alpha=10, reg_lambda=0.1, subsample=1
# [CV]  feature_fraction=1, learning_rate=0.05, min_child_samples=651, num_leaves=473, reg_alpha=10, reg_lambda=0.1, subsample=1, score=-0.367, total= 3.6min
# [Parallel(n_jobs=1)]: Done  43 out of  43 | elapsed: 130.6min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.05, min_child_samples=651, num_leaves=473, reg_alpha=10, reg_lambda=0.1, subsample=1
# [CV]  feature_fraction=1, learning_rate=0.05, min_child_samples=651, num_leaves=473, reg_alpha=10, reg_lambda=0.1, subsample=1, score=-0.349, total= 3.2min
# [Parallel(n_jobs=1)]: Done  44 out of  44 | elapsed: 133.8min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.05, min_child_samples=651, num_leaves=473, reg_alpha=10, reg_lambda=0.1, subsample=1
# [CV]  feature_fraction=1, learning_rate=0.05, min_child_samples=651, num_leaves=473, reg_alpha=10, reg_lambda=0.1, subsample=1, score=-0.368, total= 3.3min
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 137.1min remaining:    0.0s
# [CV] feature_fraction=0.5, learning_rate=0.05, min_child_samples=850, num_leaves=1210, reg_alpha=10, reg_lambda=0.1, subsample=0.9
# [CV]  feature_fraction=0.5, learning_rate=0.05, min_child_samples=850, num_leaves=1210, reg_alpha=10, reg_lambda=0.1, subsample=0.9, score=-0.373, total= 3.7min
# [Parallel(n_jobs=1)]: Done  46 out of  46 | elapsed: 140.8min remaining:    0.0s
# [CV] feature_fraction=0.5, learning_rate=0.05, min_child_samples=850, num_leaves=1210, reg_alpha=10, reg_lambda=0.1, subsample=0.9
# [CV]  feature_fraction=0.5, learning_rate=0.05, min_child_samples=850, num_leaves=1210, reg_alpha=10, reg_lambda=0.1, subsample=0.9, score=-0.358, total= 3.7min
# [Parallel(n_jobs=1)]: Done  47 out of  47 | elapsed: 144.6min remaining:    0.0s
# [CV] feature_fraction=0.5, learning_rate=0.05, min_child_samples=850, num_leaves=1210, reg_alpha=10, reg_lambda=0.1, subsample=0.9
# [CV]  feature_fraction=0.5, learning_rate=0.05, min_child_samples=850, num_leaves=1210, reg_alpha=10, reg_lambda=0.1, subsample=0.9, score=-0.373, total= 3.6min
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed: 148.2min remaining:    0.0s
# [CV] feature_fraction=0.9, learning_rate=0.01, min_child_samples=534, num_leaves=573, reg_alpha=0, reg_lambda=2, subsample=0.9
# [CV]  feature_fraction=0.9, learning_rate=0.01, min_child_samples=534, num_leaves=573, reg_alpha=0, reg_lambda=2, subsample=0.9, score=-0.457, total= 3.8min
# [Parallel(n_jobs=1)]: Done  49 out of  49 | elapsed: 152.1min remaining:    0.0s
# [CV] feature_fraction=0.9, learning_rate=0.01, min_child_samples=534, num_leaves=573, reg_alpha=0, reg_lambda=2, subsample=0.9
# [CV]  feature_fraction=0.9, learning_rate=0.01, min_child_samples=534, num_leaves=573, reg_alpha=0, reg_lambda=2, subsample=0.9, score=-0.437, total= 4.1min
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed: 156.2min remaining:    0.0s
# [CV] feature_fraction=0.9, learning_rate=0.01, min_child_samples=534, num_leaves=573, reg_alpha=0, reg_lambda=2, subsample=0.9
# [CV]  feature_fraction=0.9, learning_rate=0.01, min_child_samples=534, num_leaves=573, reg_alpha=0, reg_lambda=2, subsample=0.9, score=-0.446, total= 4.2min
# [Parallel(n_jobs=1)]: Done  51 out of  51 | elapsed: 160.3min remaining:    0.0s
# [CV] feature_fraction=0.5, learning_rate=0.1, min_child_samples=931, num_leaves=1069, reg_alpha=7, reg_lambda=7, subsample=1
# [CV]  feature_fraction=0.5, learning_rate=0.1, min_child_samples=931, num_leaves=1069, reg_alpha=7, reg_lambda=7, subsample=1, score=-0.366, total= 3.2min
# [Parallel(n_jobs=1)]: Done  52 out of  52 | elapsed: 163.5min remaining:    0.0s
# [CV] feature_fraction=0.5, learning_rate=0.1, min_child_samples=931, num_leaves=1069, reg_alpha=7, reg_lambda=7, subsample=1
# [CV]  feature_fraction=0.5, learning_rate=0.1, min_child_samples=931, num_leaves=1069, reg_alpha=7, reg_lambda=7, subsample=1, score=-0.345, total= 2.9min
# [Parallel(n_jobs=1)]: Done  53 out of  53 | elapsed: 166.4min remaining:    0.0s
# [CV] feature_fraction=0.5, learning_rate=0.1, min_child_samples=931, num_leaves=1069, reg_alpha=7, reg_lambda=7, subsample=1
# [CV]  feature_fraction=0.5, learning_rate=0.1, min_child_samples=931, num_leaves=1069, reg_alpha=7, reg_lambda=7, subsample=1, score=-0.369, total= 3.4min
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed: 169.8min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.1, min_child_samples=873, num_leaves=336, reg_alpha=10, reg_lambda=10, subsample=0.9
# [CV]  feature_fraction=1, learning_rate=0.1, min_child_samples=873, num_leaves=336, reg_alpha=10, reg_lambda=10, subsample=0.9, score=-0.370, total= 2.8min
# [Parallel(n_jobs=1)]: Done  55 out of  55 | elapsed: 172.6min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.1, min_child_samples=873, num_leaves=336, reg_alpha=10, reg_lambda=10, subsample=0.9
# [CV]  feature_fraction=1, learning_rate=0.1, min_child_samples=873, num_leaves=336, reg_alpha=10, reg_lambda=10, subsample=0.9, score=-0.345, total= 2.7min
# [Parallel(n_jobs=1)]: Done  56 out of  56 | elapsed: 175.3min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.1, min_child_samples=873, num_leaves=336, reg_alpha=10, reg_lambda=10, subsample=0.9
# [CV]  feature_fraction=1, learning_rate=0.1, min_child_samples=873, num_leaves=336, reg_alpha=10, reg_lambda=10, subsample=0.9, score=-0.371, total= 2.7min
# [Parallel(n_jobs=1)]: Done  57 out of  57 | elapsed: 178.0min remaining:    0.0s
# [CV] feature_fraction=0.6, learning_rate=0.1, min_child_samples=115, num_leaves=1038, reg_alpha=1, reg_lambda=0, subsample=0.7
# [CV]  feature_fraction=0.6, learning_rate=0.1, min_child_samples=115, num_leaves=1038, reg_alpha=1, reg_lambda=0, subsample=0.7, score=-0.365, total= 3.2min
# [Parallel(n_jobs=1)]: Done  58 out of  58 | elapsed: 181.3min remaining:    0.0s
# [CV] feature_fraction=0.6, learning_rate=0.1, min_child_samples=115, num_leaves=1038, reg_alpha=1, reg_lambda=0, subsample=0.7
# [CV]  feature_fraction=0.6, learning_rate=0.1, min_child_samples=115, num_leaves=1038, reg_alpha=1, reg_lambda=0, subsample=0.7, score=-0.340, total= 3.1min
# [Parallel(n_jobs=1)]: Done  59 out of  59 | elapsed: 184.4min remaining:    0.0s
# [CV] feature_fraction=0.6, learning_rate=0.1, min_child_samples=115, num_leaves=1038, reg_alpha=1, reg_lambda=0, subsample=0.7
# [CV]  feature_fraction=0.6, learning_rate=0.1, min_child_samples=115, num_leaves=1038, reg_alpha=1, reg_lambda=0, subsample=0.7, score=-0.368, total= 3.3min
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed: 187.7min remaining:    0.0s
# [CV] feature_fraction=0.6, learning_rate=0.1, min_child_samples=543, num_leaves=118, reg_alpha=7, reg_lambda=7, subsample=0.6
# [CV]  feature_fraction=0.6, learning_rate=0.1, min_child_samples=543, num_leaves=118, reg_alpha=7, reg_lambda=7, subsample=0.6, score=-0.372, total= 1.8min
# [Parallel(n_jobs=1)]: Done  61 out of  61 | elapsed: 189.4min remaining:    0.0s
# [CV] feature_fraction=0.6, learning_rate=0.1, min_child_samples=543, num_leaves=118, reg_alpha=7, reg_lambda=7, subsample=0.6
# [CV]  feature_fraction=0.6, learning_rate=0.1, min_child_samples=543, num_leaves=118, reg_alpha=7, reg_lambda=7, subsample=0.6, score=-0.357, total= 1.6min
# [Parallel(n_jobs=1)]: Done  62 out of  62 | elapsed: 191.0min remaining:    0.0s
# [CV] feature_fraction=0.6, learning_rate=0.1, min_child_samples=543, num_leaves=118, reg_alpha=7, reg_lambda=7, subsample=0.6
# [CV]  feature_fraction=0.6, learning_rate=0.1, min_child_samples=543, num_leaves=118, reg_alpha=7, reg_lambda=7, subsample=0.6, score=-0.370, total= 1.6min
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed: 192.7min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.1, min_child_samples=235, num_leaves=1262, reg_alpha=1, reg_lambda=2, subsample=0.8
# [CV]  feature_fraction=1, learning_rate=0.1, min_child_samples=235, num_leaves=1262, reg_alpha=1, reg_lambda=2, subsample=0.8, score=-0.367, total= 3.8min
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed: 196.5min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.1, min_child_samples=235, num_leaves=1262, reg_alpha=1, reg_lambda=2, subsample=0.8
# [CV]  feature_fraction=1, learning_rate=0.1, min_child_samples=235, num_leaves=1262, reg_alpha=1, reg_lambda=2, subsample=0.8, score=-0.339, total= 4.1min
# [Parallel(n_jobs=1)]: Done  65 out of  65 | elapsed: 200.6min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.1, min_child_samples=235, num_leaves=1262, reg_alpha=1, reg_lambda=2, subsample=0.8
# [CV]  feature_fraction=1, learning_rate=0.1, min_child_samples=235, num_leaves=1262, reg_alpha=1, reg_lambda=2, subsample=0.8, score=-0.370, total= 4.2min
# [Parallel(n_jobs=1)]: Done  66 out of  66 | elapsed: 204.8min remaining:    0.0s
# [CV] feature_fraction=0.4, learning_rate=0.1, min_child_samples=388, num_leaves=423, reg_alpha=0, reg_lambda=2, subsample=0.9
# [CV]  feature_fraction=0.4, learning_rate=0.1, min_child_samples=388, num_leaves=423, reg_alpha=0, reg_lambda=2, subsample=0.9, score=-0.378, total= 2.5min
# [Parallel(n_jobs=1)]: Done  67 out of  67 | elapsed: 207.3min remaining:    0.0s
# [CV] feature_fraction=0.4, learning_rate=0.1, min_child_samples=388, num_leaves=423, reg_alpha=0, reg_lambda=2, subsample=0.9
# [CV]  feature_fraction=0.4, learning_rate=0.1, min_child_samples=388, num_leaves=423, reg_alpha=0, reg_lambda=2, subsample=0.9, score=-0.367, total= 2.2min
# [Parallel(n_jobs=1)]: Done  68 out of  68 | elapsed: 209.6min remaining:    0.0s
# [CV] feature_fraction=0.4, learning_rate=0.1, min_child_samples=388, num_leaves=423, reg_alpha=0, reg_lambda=2, subsample=0.9
# [CV]  feature_fraction=0.4, learning_rate=0.1, min_child_samples=388, num_leaves=423, reg_alpha=0, reg_lambda=2, subsample=0.9, score=-0.376, total= 2.4min
# [Parallel(n_jobs=1)]: Done  69 out of  69 | elapsed: 211.9min remaining:    0.0s
# [CV] feature_fraction=0.6, learning_rate=0.05, min_child_samples=940, num_leaves=423, reg_alpha=1, reg_lambda=1, subsample=0.7
# [CV]  feature_fraction=0.6, learning_rate=0.05, min_child_samples=940, num_leaves=423, reg_alpha=1, reg_lambda=1, subsample=0.7, score=-0.375, total= 3.1min
# [Parallel(n_jobs=1)]: Done  70 out of  70 | elapsed: 215.0min remaining:    0.0s
# [CV] feature_fraction=0.6, learning_rate=0.05, min_child_samples=940, num_leaves=423, reg_alpha=1, reg_lambda=1, subsample=0.7
# [CV]  feature_fraction=0.6, learning_rate=0.05, min_child_samples=940, num_leaves=423, reg_alpha=1, reg_lambda=1, subsample=0.7, score=-0.358, total= 3.0min
# [Parallel(n_jobs=1)]: Done  71 out of  71 | elapsed: 218.0min remaining:    0.0s
# [CV] feature_fraction=0.6, learning_rate=0.05, min_child_samples=940, num_leaves=423, reg_alpha=1, reg_lambda=1, subsample=0.7
# [CV]  feature_fraction=0.6, learning_rate=0.05, min_child_samples=940, num_leaves=423, reg_alpha=1, reg_lambda=1, subsample=0.7, score=-0.372, total= 3.0min
# [Parallel(n_jobs=1)]: Done  72 out of  72 | elapsed: 221.0min remaining:    0.0s
# [CV] feature_fraction=0.8, learning_rate=0.1, min_child_samples=149, num_leaves=117, reg_alpha=7, reg_lambda=0, subsample=1
# [CV]  feature_fraction=0.8, learning_rate=0.1, min_child_samples=149, num_leaves=117, reg_alpha=7, reg_lambda=0, subsample=1, score=-0.369, total= 2.0min
# [Parallel(n_jobs=1)]: Done  73 out of  73 | elapsed: 223.0min remaining:    0.0s
# [CV] feature_fraction=0.8, learning_rate=0.1, min_child_samples=149, num_leaves=117, reg_alpha=7, reg_lambda=0, subsample=1
# [CV]  feature_fraction=0.8, learning_rate=0.1, min_child_samples=149, num_leaves=117, reg_alpha=7, reg_lambda=0, subsample=1, score=-0.353, total= 1.8min
# [Parallel(n_jobs=1)]: Done  74 out of  74 | elapsed: 224.8min remaining:    0.0s
# [CV] feature_fraction=0.8, learning_rate=0.1, min_child_samples=149, num_leaves=117, reg_alpha=7, reg_lambda=0, subsample=1
# [CV]  feature_fraction=0.8, learning_rate=0.1, min_child_samples=149, num_leaves=117, reg_alpha=7, reg_lambda=0, subsample=1, score=-0.371, total= 1.9min
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed: 226.7min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.1, min_child_samples=773, num_leaves=104, reg_alpha=7, reg_lambda=1, subsample=0.7
# [CV]  feature_fraction=1, learning_rate=0.1, min_child_samples=773, num_leaves=104, reg_alpha=7, reg_lambda=1, subsample=0.7, score=-0.371, total= 2.0min
# [Parallel(n_jobs=1)]: Done  76 out of  76 | elapsed: 228.7min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.1, min_child_samples=773, num_leaves=104, reg_alpha=7, reg_lambda=1, subsample=0.7
# [CV]  feature_fraction=1, learning_rate=0.1, min_child_samples=773, num_leaves=104, reg_alpha=7, reg_lambda=1, subsample=0.7, score=-0.352, total= 1.9min
# [Parallel(n_jobs=1)]: Done  77 out of  77 | elapsed: 230.6min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.1, min_child_samples=773, num_leaves=104, reg_alpha=7, reg_lambda=1, subsample=0.7
# [CV]  feature_fraction=1, learning_rate=0.1, min_child_samples=773, num_leaves=104, reg_alpha=7, reg_lambda=1, subsample=0.7, score=-0.372, total= 2.1min
# [Parallel(n_jobs=1)]: Done  78 out of  78 | elapsed: 232.7min remaining:    0.0s
# [CV] feature_fraction=0.8, learning_rate=0.05, min_child_samples=698, num_leaves=446, reg_alpha=10, reg_lambda=0.1, subsample=1
# [CV]  feature_fraction=0.8, learning_rate=0.05, min_child_samples=698, num_leaves=446, reg_alpha=10, reg_lambda=0.1, subsample=1, score=-0.368, total= 3.4min
# [Parallel(n_jobs=1)]: Done  79 out of  79 | elapsed: 236.2min remaining:    0.0s
# [CV] feature_fraction=0.8, learning_rate=0.05, min_child_samples=698, num_leaves=446, reg_alpha=10, reg_lambda=0.1, subsample=1
# [CV]  feature_fraction=0.8, learning_rate=0.05, min_child_samples=698, num_leaves=446, reg_alpha=10, reg_lambda=0.1, subsample=1, score=-0.349, total= 3.0min
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed: 239.2min remaining:    0.0s
# [CV] feature_fraction=0.8, learning_rate=0.05, min_child_samples=698, num_leaves=446, reg_alpha=10, reg_lambda=0.1, subsample=1
# [CV]  feature_fraction=0.8, learning_rate=0.05, min_child_samples=698, num_leaves=446, reg_alpha=10, reg_lambda=0.1, subsample=1, score=-0.368, total= 3.1min
# [Parallel(n_jobs=1)]: Done  81 out of  81 | elapsed: 242.2min remaining:    0.0s
# [CV] feature_fraction=0.8, learning_rate=0.01, min_child_samples=777, num_leaves=306, reg_alpha=7, reg_lambda=7, subsample=0.9
# [CV]  feature_fraction=0.8, learning_rate=0.01, min_child_samples=777, num_leaves=306, reg_alpha=7, reg_lambda=7, subsample=0.9, score=-0.474, total= 3.3min
# [Parallel(n_jobs=1)]: Done  82 out of  82 | elapsed: 245.5min remaining:    0.0s
# [CV] feature_fraction=0.8, learning_rate=0.01, min_child_samples=777, num_leaves=306, reg_alpha=7, reg_lambda=7, subsample=0.9
# [CV]  feature_fraction=0.8, learning_rate=0.01, min_child_samples=777, num_leaves=306, reg_alpha=7, reg_lambda=7, subsample=0.9, score=-0.454, total= 3.3min
# [Parallel(n_jobs=1)]: Done  83 out of  83 | elapsed: 248.8min remaining:    0.0s
# [CV] feature_fraction=0.8, learning_rate=0.01, min_child_samples=777, num_leaves=306, reg_alpha=7, reg_lambda=7, subsample=0.9
# [CV]  feature_fraction=0.8, learning_rate=0.01, min_child_samples=777, num_leaves=306, reg_alpha=7, reg_lambda=7, subsample=0.9, score=-0.464, total= 3.4min
# [Parallel(n_jobs=1)]: Done  84 out of  84 | elapsed: 252.2min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.1, min_child_samples=840, num_leaves=372, reg_alpha=10, reg_lambda=7, subsample=0.9
# [CV]  feature_fraction=1, learning_rate=0.1, min_child_samples=840, num_leaves=372, reg_alpha=10, reg_lambda=7, subsample=0.9, score=-0.369, total= 2.6min
# [Parallel(n_jobs=1)]: Done  85 out of  85 | elapsed: 254.7min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.1, min_child_samples=840, num_leaves=372, reg_alpha=10, reg_lambda=7, subsample=0.9
# [CV]  feature_fraction=1, learning_rate=0.1, min_child_samples=840, num_leaves=372, reg_alpha=10, reg_lambda=7, subsample=0.9, score=-0.345, total= 2.4min
# [Parallel(n_jobs=1)]: Done  86 out of  86 | elapsed: 257.1min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.1, min_child_samples=840, num_leaves=372, reg_alpha=10, reg_lambda=7, subsample=0.9
# [CV]  feature_fraction=1, learning_rate=0.1, min_child_samples=840, num_leaves=372, reg_alpha=10, reg_lambda=7, subsample=0.9, score=-0.371, total= 2.9min
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed: 260.0min remaining:    0.0s
# [CV] feature_fraction=0.9, learning_rate=0.01, min_child_samples=549, num_leaves=98, reg_alpha=10, reg_lambda=0, subsample=1
# [CV]  feature_fraction=0.9, learning_rate=0.01, min_child_samples=549, num_leaves=98, reg_alpha=10, reg_lambda=0, subsample=1, score=-0.497, total= 2.6min
# [Parallel(n_jobs=1)]: Done  88 out of  88 | elapsed: 262.6min remaining:    0.0s
# [CV] feature_fraction=0.9, learning_rate=0.01, min_child_samples=549, num_leaves=98, reg_alpha=10, reg_lambda=0, subsample=1
# [CV]  feature_fraction=0.9, learning_rate=0.01, min_child_samples=549, num_leaves=98, reg_alpha=10, reg_lambda=0, subsample=1, score=-0.470, total= 2.6min
# [Parallel(n_jobs=1)]: Done  89 out of  89 | elapsed: 265.2min remaining:    0.0s
# [CV] feature_fraction=0.9, learning_rate=0.01, min_child_samples=549, num_leaves=98, reg_alpha=10, reg_lambda=0, subsample=1
# [CV]  feature_fraction=0.9, learning_rate=0.01, min_child_samples=549, num_leaves=98, reg_alpha=10, reg_lambda=0, subsample=1, score=-0.479, total= 2.5min
# [Parallel(n_jobs=1)]: Done  90 out of  90 | elapsed: 267.8min remaining:    0.0s
# [CV] feature_fraction=0.7, learning_rate=0.1, min_child_samples=469, num_leaves=845, reg_alpha=0, reg_lambda=10, subsample=0.6
# [CV]  feature_fraction=0.7, learning_rate=0.1, min_child_samples=469, num_leaves=845, reg_alpha=0, reg_lambda=10, subsample=0.6, score=-0.365, total= 3.1min
# [Parallel(n_jobs=1)]: Done  91 out of  91 | elapsed: 270.8min remaining:    0.0s
# [CV] feature_fraction=0.7, learning_rate=0.1, min_child_samples=469, num_leaves=845, reg_alpha=0, reg_lambda=10, subsample=0.6
# [CV]  feature_fraction=0.7, learning_rate=0.1, min_child_samples=469, num_leaves=845, reg_alpha=0, reg_lambda=10, subsample=0.6, score=-0.341, total= 3.4min
# [Parallel(n_jobs=1)]: Done  92 out of  92 | elapsed: 274.2min remaining:    0.0s
# [CV] feature_fraction=0.7, learning_rate=0.1, min_child_samples=469, num_leaves=845, reg_alpha=0, reg_lambda=10, subsample=0.6
# [CV]  feature_fraction=0.7, learning_rate=0.1, min_child_samples=469, num_leaves=845, reg_alpha=0, reg_lambda=10, subsample=0.6, score=-0.369, total= 3.6min
# [Parallel(n_jobs=1)]: Done  93 out of  93 | elapsed: 277.8min remaining:    0.0s
# [CV] feature_fraction=0.8, learning_rate=0.01, min_child_samples=479, num_leaves=160, reg_alpha=7, reg_lambda=7, subsample=0.6
# [CV]  feature_fraction=0.8, learning_rate=0.01, min_child_samples=479, num_leaves=160, reg_alpha=7, reg_lambda=7, subsample=0.6, score=-0.489, total= 2.8min
# [Parallel(n_jobs=1)]: Done  94 out of  94 | elapsed: 280.6min remaining:    0.0s
# [CV] feature_fraction=0.8, learning_rate=0.01, min_child_samples=479, num_leaves=160, reg_alpha=7, reg_lambda=7, subsample=0.6
# [CV]  feature_fraction=0.8, learning_rate=0.01, min_child_samples=479, num_leaves=160, reg_alpha=7, reg_lambda=7, subsample=0.6, score=-0.465, total= 2.5min
# [Parallel(n_jobs=1)]: Done  95 out of  95 | elapsed: 283.2min remaining:    0.0s
# [CV] feature_fraction=0.8, learning_rate=0.01, min_child_samples=479, num_leaves=160, reg_alpha=7, reg_lambda=7, subsample=0.6
# [CV]  feature_fraction=0.8, learning_rate=0.01, min_child_samples=479, num_leaves=160, reg_alpha=7, reg_lambda=7, subsample=0.6, score=-0.474, total= 3.1min
# [Parallel(n_jobs=1)]: Done  96 out of  96 | elapsed: 286.3min remaining:    0.0s
# [CV] feature_fraction=0.5, learning_rate=0.1, min_child_samples=617, num_leaves=253, reg_alpha=2, reg_lambda=7, subsample=0.8
# [CV]  feature_fraction=0.5, learning_rate=0.1, min_child_samples=617, num_leaves=253, reg_alpha=2, reg_lambda=7, subsample=0.8, score=-0.369, total= 2.6min
# [Parallel(n_jobs=1)]: Done  97 out of  97 | elapsed: 288.8min remaining:    0.0s
# [CV] feature_fraction=0.5, learning_rate=0.1, min_child_samples=617, num_leaves=253, reg_alpha=2, reg_lambda=7, subsample=0.8
# [CV]  feature_fraction=0.5, learning_rate=0.1, min_child_samples=617, num_leaves=253, reg_alpha=2, reg_lambda=7, subsample=0.8, score=-0.352, total= 2.3min
# [Parallel(n_jobs=1)]: Done  98 out of  98 | elapsed: 291.1min remaining:    0.0s
# [CV] feature_fraction=0.5, learning_rate=0.1, min_child_samples=617, num_leaves=253, reg_alpha=2, reg_lambda=7, subsample=0.8
# [CV]  feature_fraction=0.5, learning_rate=0.1, min_child_samples=617, num_leaves=253, reg_alpha=2, reg_lambda=7, subsample=0.8, score=-0.369, total= 2.4min
# [Parallel(n_jobs=1)]: Done  99 out of  99 | elapsed: 293.5min remaining:    0.0s
# [CV] feature_fraction=0.5, learning_rate=0.05, min_child_samples=331, num_leaves=632, reg_alpha=7, reg_lambda=10, subsample=0.8
# [CV]  feature_fraction=0.5, learning_rate=0.05, min_child_samples=331, num_leaves=632, reg_alpha=7, reg_lambda=10, subsample=0.8, score=-0.378, total= 3.2min
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed: 296.7min remaining:    0.0s
# [CV] feature_fraction=0.5, learning_rate=0.05, min_child_samples=331, num_leaves=632, reg_alpha=7, reg_lambda=10, subsample=0.8
# [CV]  feature_fraction=0.5, learning_rate=0.05, min_child_samples=331, num_leaves=632, reg_alpha=7, reg_lambda=10, subsample=0.8, score=-0.363, total= 2.8min
# [Parallel(n_jobs=1)]: Done 101 out of 101 | elapsed: 299.6min remaining:    0.0s
# [CV] feature_fraction=0.5, learning_rate=0.05, min_child_samples=331, num_leaves=632, reg_alpha=7, reg_lambda=10, subsample=0.8
# [CV]  feature_fraction=0.5, learning_rate=0.05, min_child_samples=331, num_leaves=632, reg_alpha=7, reg_lambda=10, subsample=0.8, score=-0.374, total= 3.0min
# [Parallel(n_jobs=1)]: Done 102 out of 102 | elapsed: 302.5min remaining:    0.0s
# [CV] feature_fraction=0.7, learning_rate=0.1, min_child_samples=713, num_leaves=507, reg_alpha=0.1, reg_lambda=10, subsample=0.6
# [CV]  feature_fraction=0.7, learning_rate=0.1, min_child_samples=713, num_leaves=507, reg_alpha=0.1, reg_lambda=10, subsample=0.6, score=-0.366, total= 2.9min
# [Parallel(n_jobs=1)]: Done 103 out of 103 | elapsed: 305.4min remaining:    0.0s
# [CV] feature_fraction=0.7, learning_rate=0.1, min_child_samples=713, num_leaves=507, reg_alpha=0.1, reg_lambda=10, subsample=0.6
# [CV]  feature_fraction=0.7, learning_rate=0.1, min_child_samples=713, num_leaves=507, reg_alpha=0.1, reg_lambda=10, subsample=0.6, score=-0.344, total= 3.0min
# [Parallel(n_jobs=1)]: Done 104 out of 104 | elapsed: 308.5min remaining:    0.0s
# [CV] feature_fraction=0.7, learning_rate=0.1, min_child_samples=713, num_leaves=507, reg_alpha=0.1, reg_lambda=10, subsample=0.6
# [CV]  feature_fraction=0.7, learning_rate=0.1, min_child_samples=713, num_leaves=507, reg_alpha=0.1, reg_lambda=10, subsample=0.6, score=-0.369, total= 3.2min
# [Parallel(n_jobs=1)]: Done 105 out of 105 | elapsed: 311.7min remaining:    0.0s
# [CV] feature_fraction=0.6, learning_rate=0.05, min_child_samples=504, num_leaves=477, reg_alpha=0, reg_lambda=7, subsample=0.6
# [CV]  feature_fraction=0.6, learning_rate=0.05, min_child_samples=504, num_leaves=477, reg_alpha=0, reg_lambda=7, subsample=0.6, score=-0.373, total= 2.8min
# [Parallel(n_jobs=1)]: Done 106 out of 106 | elapsed: 314.4min remaining:    0.0s
# [CV] feature_fraction=0.6, learning_rate=0.05, min_child_samples=504, num_leaves=477, reg_alpha=0, reg_lambda=7, subsample=0.6
# [CV]  feature_fraction=0.6, learning_rate=0.05, min_child_samples=504, num_leaves=477, reg_alpha=0, reg_lambda=7, subsample=0.6, score=-0.357, total= 2.5min
# [Parallel(n_jobs=1)]: Done 107 out of 107 | elapsed: 316.9min remaining:    0.0s
# [CV] feature_fraction=0.6, learning_rate=0.05, min_child_samples=504, num_leaves=477, reg_alpha=0, reg_lambda=7, subsample=0.6
# [CV]  feature_fraction=0.6, learning_rate=0.05, min_child_samples=504, num_leaves=477, reg_alpha=0, reg_lambda=7, subsample=0.6, score=-0.371, total= 3.1min
# [Parallel(n_jobs=1)]: Done 108 out of 108 | elapsed: 320.0min remaining:    0.0s
# [CV] feature_fraction=0.7, learning_rate=0.05, min_child_samples=321, num_leaves=934, reg_alpha=10, reg_lambda=0, subsample=0.9
# [CV]  feature_fraction=0.7, learning_rate=0.05, min_child_samples=321, num_leaves=934, reg_alpha=10, reg_lambda=0, subsample=0.9, score=-0.366, total= 3.9min
# [Parallel(n_jobs=1)]: Done 109 out of 109 | elapsed: 323.9min remaining:    0.0s
# [CV] feature_fraction=0.7, learning_rate=0.05, min_child_samples=321, num_leaves=934, reg_alpha=10, reg_lambda=0, subsample=0.9
# [CV]  feature_fraction=0.7, learning_rate=0.05, min_child_samples=321, num_leaves=934, reg_alpha=10, reg_lambda=0, subsample=0.9, score=-0.347, total= 3.7min
# [Parallel(n_jobs=1)]: Done 110 out of 110 | elapsed: 327.6min remaining:    0.0s
# [CV] feature_fraction=0.7, learning_rate=0.05, min_child_samples=321, num_leaves=934, reg_alpha=10, reg_lambda=0, subsample=0.9
# [CV]  feature_fraction=0.7, learning_rate=0.05, min_child_samples=321, num_leaves=934, reg_alpha=10, reg_lambda=0, subsample=0.9, score=-0.368, total= 3.6min
# [Parallel(n_jobs=1)]: Done 111 out of 111 | elapsed: 331.2min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.01, min_child_samples=951, num_leaves=1206, reg_alpha=0, reg_lambda=1, subsample=0.7
# [CV]  feature_fraction=1, learning_rate=0.01, min_child_samples=951, num_leaves=1206, reg_alpha=0, reg_lambda=1, subsample=0.7, score=-0.440, total= 5.5min
# [Parallel(n_jobs=1)]: Done 112 out of 112 | elapsed: 336.7min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.01, min_child_samples=951, num_leaves=1206, reg_alpha=0, reg_lambda=1, subsample=0.7
# [CV]  feature_fraction=1, learning_rate=0.01, min_child_samples=951, num_leaves=1206, reg_alpha=0, reg_lambda=1, subsample=0.7, score=-0.424, total= 5.2min
# [Parallel(n_jobs=1)]: Done 113 out of 113 | elapsed: 341.9min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.01, min_child_samples=951, num_leaves=1206, reg_alpha=0, reg_lambda=1, subsample=0.7
# [CV]  feature_fraction=1, learning_rate=0.01, min_child_samples=951, num_leaves=1206, reg_alpha=0, reg_lambda=1, subsample=0.7, score=-0.433, total= 4.8min
# [Parallel(n_jobs=1)]: Done 114 out of 114 | elapsed: 346.7min remaining:    0.0s
# [CV] feature_fraction=0.4, learning_rate=0.1, min_child_samples=969, num_leaves=953, reg_alpha=0, reg_lambda=1, subsample=0.8
# [CV]  feature_fraction=0.4, learning_rate=0.1, min_child_samples=969, num_leaves=953, reg_alpha=0, reg_lambda=1, subsample=0.8, score=-0.375, total= 3.4min
# [Parallel(n_jobs=1)]: Done 115 out of 115 | elapsed: 350.1min remaining:    0.0s
# [CV] feature_fraction=0.4, learning_rate=0.1, min_child_samples=969, num_leaves=953, reg_alpha=0, reg_lambda=1, subsample=0.8
# [CV]  feature_fraction=0.4, learning_rate=0.1, min_child_samples=969, num_leaves=953, reg_alpha=0, reg_lambda=1, subsample=0.8, score=-0.360, total= 3.1min
# [Parallel(n_jobs=1)]: Done 116 out of 116 | elapsed: 353.2min remaining:    0.0s
# [CV] feature_fraction=0.4, learning_rate=0.1, min_child_samples=969, num_leaves=953, reg_alpha=0, reg_lambda=1, subsample=0.8
# [CV]  feature_fraction=0.4, learning_rate=0.1, min_child_samples=969, num_leaves=953, reg_alpha=0, reg_lambda=1, subsample=0.8, score=-0.374, total= 3.3min
# [Parallel(n_jobs=1)]: Done 117 out of 117 | elapsed: 356.6min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.01, min_child_samples=523, num_leaves=771, reg_alpha=10, reg_lambda=0.1, subsample=0.7
# [CV]  feature_fraction=1, learning_rate=0.01, min_child_samples=523, num_leaves=771, reg_alpha=10, reg_lambda=0.1, subsample=0.7, score=-0.448, total= 4.3min
# [Parallel(n_jobs=1)]: Done 118 out of 118 | elapsed: 360.8min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.01, min_child_samples=523, num_leaves=771, reg_alpha=10, reg_lambda=0.1, subsample=0.7
# [CV]  feature_fraction=1, learning_rate=0.01, min_child_samples=523, num_leaves=771, reg_alpha=10, reg_lambda=0.1, subsample=0.7, score=-0.430, total= 4.8min
# [Parallel(n_jobs=1)]: Done 119 out of 119 | elapsed: 365.6min remaining:    0.0s
# [CV] feature_fraction=1, learning_rate=0.01, min_child_samples=523, num_leaves=771, reg_alpha=10, reg_lambda=0.1, subsample=0.7
# [CV]  feature_fraction=1, learning_rate=0.01, min_child_samples=523, num_leaves=771, reg_alpha=10, reg_lambda=0.1, subsample=0.7, score=-0.438, total= 4.8min
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed: 370.4min remaining:    0.0s
# [CV] feature_fraction=0.9, learning_rate=0.1, min_child_samples=926, num_leaves=1003, reg_alpha=10, reg_lambda=7, subsample=1
# [CV]  feature_fraction=0.9, learning_rate=0.1, min_child_samples=926, num_leaves=1003, reg_alpha=10, reg_lambda=7, subsample=1, score=-0.366, total= 3.6min
# [Parallel(n_jobs=1)]: Done 121 out of 121 | elapsed: 374.0min remaining:    0.0s
# [CV] feature_fraction=0.9, learning_rate=0.1, min_child_samples=926, num_leaves=1003, reg_alpha=10, reg_lambda=7, subsample=1
# [CV]  feature_fraction=0.9, learning_rate=0.1, min_child_samples=926, num_leaves=1003, reg_alpha=10, reg_lambda=7, subsample=1, score=-0.339, total= 3.6min
# [Parallel(n_jobs=1)]: Done 122 out of 122 | elapsed: 377.6min remaining:    0.0s
# [CV] feature_fraction=0.9, learning_rate=0.1, min_child_samples=926, num_leaves=1003, reg_alpha=10, reg_lambda=7, subsample=1
# [CV]  feature_fraction=0.9, learning_rate=0.1, min_child_samples=926, num_leaves=1003, reg_alpha=10, reg_lambda=7, subsample=1, score=-0.370, total= 4.0min
# [Parallel(n_jobs=1)]: Done 123 out of 123 | elapsed: 381.6min remaining:    0.0s
# [CV] feature_fraction=0.9, learning_rate=0.05, min_child_samples=553, num_leaves=1092, reg_alpha=0, reg_lambda=0.1, subsample=0.7
# [CV]  feature_fraction=0.9, learning_rate=0.05, min_child_samples=553, num_leaves=1092, reg_alpha=0, reg_lambda=0.1, subsample=0.7, score=-0.364, total= 4.4min
# [Parallel(n_jobs=1)]: Done 124 out of 124 | elapsed: 386.1min remaining:    0.0s
# [CV] feature_fraction=0.9, learning_rate=0.05, min_child_samples=553, num_leaves=1092, reg_alpha=0, reg_lambda=0.1, subsample=0.7
# [CV]  feature_fraction=0.9, learning_rate=0.05, min_child_samples=553, num_leaves=1092, reg_alpha=0, reg_lambda=0.1, subsample=0.7, score=-0.340, total= 4.0min
# [Parallel(n_jobs=1)]: Done 125 out of 125 | elapsed: 390.1min remaining:    0.0s
# [CV] feature_fraction=0.9, learning_rate=0.05, min_child_samples=553, num_leaves=1092, reg_alpha=0, reg_lambda=0.1, subsample=0.7
# [CV]  feature_fraction=0.9, learning_rate=0.05, min_child_samples=553, num_leaves=1092, reg_alpha=0, reg_lambda=0.1, subsample=0.7, score=-0.366, total= 3.9min
# [Parallel(n_jobs=1)]: Done 126 out of 126 | elapsed: 394.0min remaining:    0.0s
# [CV] feature_fraction=0.9, learning_rate=0.05, min_child_samples=738, num_leaves=298, reg_alpha=7, reg_lambda=0, subsample=0.6
# [CV]  feature_fraction=0.9, learning_rate=0.05, min_child_samples=738, num_leaves=298, reg_alpha=7, reg_lambda=0, subsample=0.6, score=-0.369, total= 2.6min
# [Parallel(n_jobs=1)]: Done 127 out of 127 | elapsed: 396.6min remaining:    0.0s
# [CV] feature_fraction=0.9, learning_rate=0.05, min_child_samples=738, num_leaves=298, reg_alpha=7, reg_lambda=0, subsample=0.6
# [CV]  feature_fraction=0.9, learning_rate=0.05, min_child_samples=738, num_leaves=298, reg_alpha=7, reg_lambda=0, subsample=0.6, score=-0.352, total= 2.7min
# [Parallel(n_jobs=1)]: Done 128 out of 128 | elapsed: 399.3min remaining:    0.0s
# [CV] feature_fraction=0.9, learning_rate=0.05, min_child_samples=738, num_leaves=298, reg_alpha=7, reg_lambda=0, subsample=0.6
# [CV]  feature_fraction=0.9, learning_rate=0.05, min_child_samples=738, num_leaves=298, reg_alpha=7, reg_lambda=0, subsample=0.6, score=-0.368, total= 2.6min
# [Parallel(n_jobs=1)]: Done 129 out of 129 | elapsed: 402.0min remaining:    0.0s
# [CV] feature_fraction=0.6, learning_rate=0.01, min_child_samples=745, num_leaves=1030, reg_alpha=0, reg_lambda=0.1, subsample=0.8
# ...
# [CV]  feature_fraction=0.5, learning_rate=0.01, min_child_samples=472, num_leaves=873, reg_alpha=2, reg_lambda=10, subsample=0.8, score=-0.465, total= 3.7min
# [CV] feature_fraction=0.5, learning_rate=0.01, min_child_samples=472, num_leaves=873, reg_alpha=2, reg_lambda=10, subsample=0.8
# [CV]  feature_fraction=0.5, learning_rate=0.01, min_child_samples=472, num_leaves=873, reg_alpha=2, reg_lambda=10, subsample=0.8, score=-0.474, total= 3.7min
# [CV] feature_fraction=0.4, learning_rate=0.1, min_child_samples=856, num_leaves=1267, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8
# [CV]  feature_fraction=0.4, learning_rate=0.1, min_child_samples=856, num_leaves=1267, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, score=-0.375, total= 3.7min
# [CV] feature_fraction=0.4, learning_rate=0.1, min_child_samples=856, num_leaves=1267, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8
# [CV]  feature_fraction=0.4, learning_rate=0.1, min_child_samples=856, num_leaves=1267, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, score=-0.359, total= 3.1min
# [CV] feature_fraction=0.4, learning_rate=0.1, min_child_samples=856, num_leaves=1267, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8
# [CV]  feature_fraction=0.4, learning_rate=0.1, min_child_samples=856, num_leaves=1267, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, score=-0.374, total= 3.4min
# [CV] feature_fraction=0.9, learning_rate=0.01, min_child_samples=748, num_leaves=678, reg_alpha=10, reg_lambda=10, subsample=0.8
# [CV]  feature_fraction=0.9, learning_rate=0.01, min_child_samples=748, num_leaves=678, reg_alpha=10, reg_lambda=10, subsample=0.8, score=-0.453, total= 4.5min
# [CV] feature_fraction=0.9, learning_rate=0.01, min_child_samples=748, num_leaves=678, reg_alpha=10, reg_lambda=10, subsample=0.8
# [CV]  feature_fraction=0.9, learning_rate=0.01, min_child_samples=748, num_leaves=678, reg_alpha=10, reg_lambda=10, subsample=0.8, score=-0.434, total= 4.5min
# [CV] feature_fraction=0.9, learning_rate=0.01, min_child_samples=748, num_leaves=678, reg_alpha=10, reg_lambda=10, subsample=0.8
# [CV]  feature_fraction=0.9, learning_rate=0.01, min_child_samples=748, num_leaves=678, reg_alpha=10, reg_lambda=10, subsample=0.8, score=-0.444, total= 4.0min
# [CV] feature_fraction=0.6, learning_rate=0.01, min_child_samples=827, num_leaves=1173, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9
# [CV]  feature_fraction=0.6, learning_rate=0.01, min_child_samples=827, num_leaves=1173, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9, score=-0.472, total= 4.4min
# [CV] feature_fraction=0.6, learning_rate=0.01, min_child_samples=827, num_leaves=1173, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9
# [CV]  feature_fraction=0.6, learning_rate=0.01, min_child_samples=827, num_leaves=1173, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9, score=-0.453, total= 4.3min
# [CV] feature_fraction=0.6, learning_rate=0.01, min_child_samples=827, num_leaves=1173, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9
# [CV]  feature_fraction=0.6, learning_rate=0.01, min_child_samples=827, num_leaves=1173, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9, score=-0.463, total= 3.9min
# [CV] feature_fraction=0.7, learning_rate=0.1, min_child_samples=717, num_leaves=1133, reg_alpha=10, reg_lambda=10, subsample=1
# [CV]  feature_fraction=0.7, learning_rate=0.1, min_child_samples=717, num_leaves=1133, reg_alpha=10, reg_lambda=10, subsample=1, score=-0.365, total= 3.4min
# [CV] feature_fraction=0.7, learning_rate=0.1, min_child_samples=717, num_leaves=1133, reg_alpha=10, reg_lambda=10, subsample=1
# [CV]  feature_fraction=0.7, learning_rate=0.1, min_child_samples=717, num_leaves=1133, reg_alpha=10, reg_lambda=10, subsample=1, score=-0.342, total= 3.9min
# [CV] feature_fraction=0.7, learning_rate=0.1, min_child_samples=717, num_leaves=1133, reg_alpha=10, reg_lambda=10, subsample=1
# [CV]  feature_fraction=0.7, learning_rate=0.1, min_child_samples=717, num_leaves=1133, reg_alpha=10, reg_lambda=10, subsample=1, score=-0.369, total= 3.9min
# [CV] feature_fraction=0.7, learning_rate=0.1, min_child_samples=570, num_leaves=231, reg_alpha=1, reg_lambda=0.1, subsample=1
# [CV]  feature_fraction=0.7, learning_rate=0.1, min_child_samples=570, num_leaves=231, reg_alpha=1, reg_lambda=0.1, subsample=1, score=-0.367, total= 2.6min
# [CV] feature_fraction=0.7, learning_rate=0.1, min_child_samples=570, num_leaves=231, reg_alpha=1, reg_lambda=0.1, subsample=1
# [CV]  feature_fraction=0.7, learning_rate=0.1, min_child_samples=570, num_leaves=231, reg_alpha=1, reg_lambda=0.1, subsample=1, score=-0.348, total= 2.2min
# [CV] feature_fraction=0.7, learning_rate=0.1, min_child_samples=570, num_leaves=231, reg_alpha=1, reg_lambda=0.1, subsample=1
# [CV]  feature_fraction=0.7, learning_rate=0.1, min_child_samples=570, num_leaves=231, reg_alpha=1, reg_lambda=0.1, subsample=1, score=-0.370, total= 2.2min
# [CV] feature_fraction=0.6, learning_rate=0.01, min_child_samples=723, num_leaves=149, reg_alpha=0, reg_lambda=0, subsample=0.6
# [CV]  feature_fraction=0.6, learning_rate=0.01, min_child_samples=723, num_leaves=149, reg_alpha=0, reg_lambda=0, subsample=0.6, score=-0.499, total= 2.2min
# [CV] feature_fraction=0.6, learning_rate=0.01, min_child_samples=723, num_leaves=149, reg_alpha=0, reg_lambda=0, subsample=0.6
# [CV]  feature_fraction=0.6, learning_rate=0.01, min_child_samples=723, num_leaves=149, reg_alpha=0, reg_lambda=0, subsample=0.6, score=-0.476, total= 2.5min
# [CV] feature_fraction=0.6, learning_rate=0.01, min_child_samples=723, num_leaves=149, reg_alpha=0, reg_lambda=0, subsample=0.6
# [CV]  feature_fraction=0.6, learning_rate=0.01, min_child_samples=723, num_leaves=149, reg_alpha=0, reg_lambda=0, subsample=0.6, score=-0.486, total= 2.6min
# [CV] feature_fraction=1, learning_rate=0.01, min_child_samples=787, num_leaves=737, reg_alpha=0.1, reg_lambda=10, subsample=0.6
# [CV]  feature_fraction=1, learning_rate=0.01, min_child_samples=787, num_leaves=737, reg_alpha=0.1, reg_lambda=10, subsample=0.6, score=-0.449, total= 4.3min
# [CV] feature_fraction=1, learning_rate=0.01, min_child_samples=787, num_leaves=737, reg_alpha=0.1, reg_lambda=10, subsample=0.6
# [CV]  feature_fraction=1, learning_rate=0.01, min_child_samples=787, num_leaves=737, reg_alpha=0.1, reg_lambda=10, subsample=0.6, score=-0.431, total= 4.2min
# [CV] feature_fraction=1, learning_rate=0.01, min_child_samples=787, num_leaves=737, reg_alpha=0.1, reg_lambda=10, subsample=0.6
# [CV]  feature_fraction=1, learning_rate=0.01, min_child_samples=787, num_leaves=737, reg_alpha=0.1, reg_lambda=10, subsample=0.6, score=-0.439, total= 4.8min
# [CV] feature_fraction=1, learning_rate=0.01, min_child_samples=352, num_leaves=1062, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9
# [CV]  feature_fraction=1, learning_rate=0.01, min_child_samples=352, num_leaves=1062, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9, score=-0.442, total= 5.4min
# [CV] feature_fraction=1, learning_rate=0.01, min_child_samples=352, num_leaves=1062, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9
# [CV]  feature_fraction=1, learning_rate=0.01, min_child_samples=352, num_leaves=1062, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9, score=-0.426, total= 4.7min
# [CV] feature_fraction=1, learning_rate=0.01, min_child_samples=352, num_leaves=1062, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9
# [CV]  feature_fraction=1, learning_rate=0.01, min_child_samples=352, num_leaves=1062, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9, score=-0.434, total= 5.2min
# [CV] feature_fraction=0.9, learning_rate=0.01, min_child_samples=991, num_leaves=629, reg_alpha=1, reg_lambda=10, subsample=0.9
# [CV]  feature_fraction=0.9, learning_rate=0.01, min_child_samples=991, num_leaves=629, reg_alpha=1, reg_lambda=10, subsample=0.9, score=-0.455, total= 4.2min
# [CV] feature_fraction=0.9, learning_rate=0.01, min_child_samples=991, num_leaves=629, reg_alpha=1, reg_lambda=10, subsample=0.9
# [CV]  feature_fraction=0.9, learning_rate=0.01, min_child_samples=991, num_leaves=629, reg_alpha=1, reg_lambda=10, subsample=0.9, score=-0.436, total= 3.9min
# [CV] feature_fraction=0.9, learning_rate=0.01, min_child_samples=991, num_leaves=629, reg_alpha=1, reg_lambda=10, subsample=0.9
# [CV]  feature_fraction=0.9, learning_rate=0.01, min_child_samples=991, num_leaves=629, reg_alpha=1, reg_lambda=10, subsample=0.9, score=-0.445, total= 4.7min
# [CV] feature_fraction=0.9, learning_rate=0.01, min_child_samples=226, num_leaves=265, reg_alpha=0.1, reg_lambda=1, subsample=0.6
# [CV]  feature_fraction=0.9, learning_rate=0.01, min_child_samples=226, num_leaves=265, reg_alpha=0.1, reg_lambda=1, subsample=0.6, score=-0.472, total= 3.1min
# [CV] feature_fraction=0.9, learning_rate=0.01, min_child_samples=226, num_leaves=265, reg_alpha=0.1, reg_lambda=1, subsample=0.6
# [CV]  feature_fraction=0.9, learning_rate=0.01, min_child_samples=226, num_leaves=265, reg_alpha=0.1, reg_lambda=1, subsample=0.6, score=-0.451, total= 3.1min
# [CV] feature_fraction=0.9, learning_rate=0.01, min_child_samples=226, num_leaves=265, reg_alpha=0.1, reg_lambda=1, subsample=0.6
# [CV]  feature_fraction=0.9, learning_rate=0.01, min_child_samples=226, num_leaves=265, reg_alpha=0.1, reg_lambda=1, subsample=0.6, score=-0.461, total= 2.9min
# [CV] feature_fraction=0.4, learning_rate=0.1, min_child_samples=381, num_leaves=448, reg_alpha=0.1, reg_lambda=10, subsample=0.9
# [CV]  feature_fraction=0.4, learning_rate=0.1, min_child_samples=381, num_leaves=448, reg_alpha=0.1, reg_lambda=10, subsample=0.9, score=-0.378, total= 2.4min
# [CV] feature_fraction=0.4, learning_rate=0.1, min_child_samples=381, num_leaves=448, reg_alpha=0.1, reg_lambda=10, subsample=0.9
# [CV]  feature_fraction=0.4, learning_rate=0.1, min_child_samples=381, num_leaves=448, reg_alpha=0.1, reg_lambda=10, subsample=0.9, score=-0.366, total= 2.5min
# [CV] feature_fraction=0.4, learning_rate=0.1, min_child_samples=381, num_leaves=448, reg_alpha=0.1, reg_lambda=10, subsample=0.9
# [CV]  feature_fraction=0.4, learning_rate=0.1, min_child_samples=381, num_leaves=448, reg_alpha=0.1, reg_lambda=10, subsample=0.9, score=-0.376, total= 2.9min
# [CV] feature_fraction=1, learning_rate=0.01, min_child_samples=648, num_leaves=489, reg_alpha=0.1, reg_lambda=0.1, subsample=1
# [CV]  feature_fraction=1, learning_rate=0.01, min_child_samples=648, num_leaves=489, reg_alpha=0.1, reg_lambda=0.1, subsample=1, score=-0.457, total= 4.5min
# [CV] feature_fraction=1, learning_rate=0.01, min_child_samples=648, num_leaves=489, reg_alpha=0.1, reg_lambda=0.1, subsample=1
# [CV]  feature_fraction=1, learning_rate=0.01, min_child_samples=648, num_leaves=489, reg_alpha=0.1, reg_lambda=0.1, subsample=1, score=-0.439, total= 4.0min
# [CV] feature_fraction=1, learning_rate=0.01, min_child_samples=648, num_leaves=489, reg_alpha=0.1, reg_lambda=0.1, subsample=1
# [CV]  feature_fraction=1, learning_rate=0.01, min_child_samples=648, num_leaves=489, reg_alpha=0.1, reg_lambda=0.1, subsample=1, score=-0.447, total= 4.5min
# [CV] feature_fraction=0.8, learning_rate=0.05, min_child_samples=873, num_leaves=1176, reg_alpha=10, reg_lambda=7, subsample=0.7
# [CV]  feature_fraction=0.8, learning_rate=0.05, min_child_samples=873, num_leaves=1176, reg_alpha=10, reg_lambda=7, subsample=0.7, score=-0.364, total= 4.7min
# [CV] feature_fraction=0.8, learning_rate=0.05, min_child_samples=873, num_leaves=1176, reg_alpha=10, reg_lambda=7, subsample=0.7
# [CV]  feature_fraction=0.8, learning_rate=0.05, min_child_samples=873, num_leaves=1176, reg_alpha=10, reg_lambda=7, subsample=0.7, score=-0.341, total= 4.1min
# [CV] feature_fraction=0.8, learning_rate=0.05, min_child_samples=873, num_leaves=1176, reg_alpha=10, reg_lambda=7, subsample=0.7
# [CV]  feature_fraction=0.8, learning_rate=0.05, min_child_samples=873, num_leaves=1176, reg_alpha=10, reg_lambda=7, subsample=0.7, score=-0.367, total= 4.2min
# [CV] feature_fraction=1, learning_rate=0.1, min_child_samples=237, num_leaves=936, reg_alpha=0.1, reg_lambda=0.1, subsample=0.6
# [CV]  feature_fraction=1, learning_rate=0.1, min_child_samples=237, num_leaves=936, reg_alpha=0.1, reg_lambda=0.1, subsample=0.6, score=-0.367, total= 3.5min
# [CV] feature_fraction=1, learning_rate=0.1, min_child_samples=237, num_leaves=936, reg_alpha=0.1, reg_lambda=0.1, subsample=0.6
# [CV]  feature_fraction=1, learning_rate=0.1, min_child_samples=237, num_leaves=936, reg_alpha=0.1, reg_lambda=0.1, subsample=0.6, score=-0.340, total= 3.9min
# [CV] feature_fraction=1, learning_rate=0.1, min_child_samples=237, num_leaves=936, reg_alpha=0.1, reg_lambda=0.1, subsample=0.6
# [CV]  feature_fraction=1, learning_rate=0.1, min_child_samples=237, num_leaves=936, reg_alpha=0.1, reg_lambda=0.1, subsample=0.6, score=-0.370, total= 3.8min
# [CV] feature_fraction=0.5, learning_rate=0.01, min_child_samples=899, num_leaves=506, reg_alpha=7, reg_lambda=0.1, subsample=0.7
# [CV]  feature_fraction=0.5, learning_rate=0.01, min_child_samples=899, num_leaves=506, reg_alpha=7, reg_lambda=0.1, subsample=0.7, score=-0.490, total= 3.1min
# [CV] feature_fraction=0.5, learning_rate=0.01, min_child_samples=899, num_leaves=506, reg_alpha=7, reg_lambda=0.1, subsample=0.7
# [CV]  feature_fraction=0.5, learning_rate=0.01, min_child_samples=899, num_leaves=506, reg_alpha=7, reg_lambda=0.1, subsample=0.7, score=-0.470, total= 3.1min
# [CV] feature_fraction=0.5, learning_rate=0.01, min_child_samples=899, num_leaves=506, reg_alpha=7, reg_lambda=0.1, subsample=0.7
# [CV]  feature_fraction=0.5, learning_rate=0.01, min_child_samples=899, num_leaves=506, reg_alpha=7, reg_lambda=0.1, subsample=0.7, score=-0.480, total= 3.2min
# [CV] feature_fraction=0.9, learning_rate=0.01, min_child_samples=286, num_leaves=1218, reg_alpha=2, reg_lambda=10, subsample=0.8
# [CV]  feature_fraction=0.9, learning_rate=0.01, min_child_samples=286, num_leaves=1218, reg_alpha=2, reg_lambda=10, subsample=0.8, score=-0.444, total= 5.4min
# [CV] feature_fraction=0.9, learning_rate=0.01, min_child_samples=286, num_leaves=1218, reg_alpha=2, reg_lambda=10, subsample=0.8
# [CV]  feature_fraction=0.9, learning_rate=0.01, min_child_samples=286, num_leaves=1218, reg_alpha=2, reg_lambda=10, subsample=0.8, score=-0.427, total= 5.2min
# [CV] feature_fraction=0.9, learning_rate=0.01, min_child_samples=286, num_leaves=1218, reg_alpha=2, reg_lambda=10, subsample=0.8
# [CV]  feature_fraction=0.9, learning_rate=0.01, min_child_samples=286, num_leaves=1218, reg_alpha=2, reg_lambda=10, subsample=0.8, score=-0.436, total= 5.7min
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed: 970.5min finished
# RandomizedSearchCV(cv=3, error_score='raise-deprecating',
#                    estimator=LGBMRegressor(boosting_type='gbdt',
#                                            class_weight=None,
#                                            colsample_bytree=1.0,
#                                            importance_type='split',
#                                            learning_rate=0.1, max_depth=-1,
#                                            min_child_samples=20,
#                                            min_child_weight=0.001,
#                                            min_split_gain=0.0, n_estimators=100,
#                                            n_jobs=-1, num_leaves=31,
#                                            objective='regression',
#                                            random_state=None, reg_alpha=...
#                                         'min_child_samples': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001FC19CABDA0>,
#                                         'num_leaves': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001FC19CABBE0>,
#                                         'reg_alpha': [0, 0.1, 1, 2, 7, 10],
#                                         'reg_lambda': [0, 0.1, 1, 2, 7, 10],
#                                         'subsample': [0.6, 0.7, 0.8, 0.9, 1]},
#                    pre_dispatch='2*n_jobs', random_state=314, refit=True,
#                    return_train_score=False,
#                    scoring=make_scorer(rmsle, greater_is_better=False),
#                    verbose=200)

# %%
print(gs.best_params_)
# Out:
# {'feature_fraction': 0.9, 'learning_rate': 0.05, 'min_child_samples': 553, 'num_leaves': 1092, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 0.7}

# %%
best_mdl = gs.best_estimator_
best_mdl
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               feature_fraction=0.9, importance_type='split', learning_rate=0.05,
#               max_depth=-1, min_child_samples=553, min_child_weight=0.001,
#               min_split_gain=0.0, n_estimators=100, n_jobs=-1, num_leaves=1092,
#               objective='regression', random_state=None, reg_alpha=0,
#               reg_lambda=0.1, silent=0, subsample=0.7, subsample_for_bin=200000,
#               subsample_freq=0)

# %%
results = pd.DataFrame(gs.cv_results_)
results.head(150)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      117.348981      4.284950        45.813446        2.578928
# 1       74.787462      1.728945        28.639091        0.500438
# 2      242.128626     20.113821        49.342728        1.444292
# 3      144.129398      6.254157        50.515705        2.837559
# 4      125.322912      2.471132        35.560721        0.834106
# 5      181.478473     11.375203        52.566665        4.112759
# 6       89.225371      8.461391        32.034931        0.256247
# 7      147.872709      0.812150        48.874631        1.942184
# 8      107.838387     19.484845        40.636893        1.530686
# 9      195.050645      9.614584        59.297577        1.491574
# 10     137.197859     12.313167        44.455738        0.960870
# 11     105.115719      9.981750        42.046571        2.894989
# 12     140.744063      5.562552        52.234025        0.131278
# 13     108.215595      7.084831        39.640233        1.598543
# 14     157.736280      6.622491        43.746701        3.217986
# 15     164.748411      2.447304        57.136490        2.505618
# 16     196.235430      6.587533        46.030683        2.422587
# 17     133.234554      7.607849        56.198199        4.282084
# 18     124.226287      1.204636        40.423848        1.608786
# 19     137.323683      3.313122        55.242285        1.756467
# 20      71.915077      4.763164        28.092863        0.325502
# 21     181.774942      7.762351        60.919180        2.914670
# 22     100.694977      6.308849        41.564129        1.402446
# 23     133.489819      0.798261        47.639174        1.367426
# 24      86.225795      3.101096        26.973710        0.731640
# 25      92.858732      3.968471        28.009089        0.594439
# 26     145.291331      8.875933        44.640606        2.548528
# 27     157.010010      2.907399        41.123789        1.345629
# 28     116.140939     11.069143        40.768987        2.449783
# 29     125.383296      1.466449        29.600363        0.641346
# 30     147.053572      9.834363        53.551115        3.439368
# 31     135.572083     14.655423        33.790558        1.767060
# 32     104.600026      6.041070        39.339753        1.561944
# 33     130.693799      7.741119        49.485785        3.916962
# 34     134.094899      4.684028        48.920844        2.322432
# 35     119.347288     12.017807        47.048142        2.284839
# 36     171.549935      6.750369        52.375985        3.627244
# 37     257.679868     14.530404        52.505205        5.214806
# 38     139.820246      3.806062        57.150426        2.037137
# 39     228.311524     12.937559        49.036818        2.754940
# 40     162.777876     10.191036        61.172620        2.970615
# 41     192.367923      9.850564        53.972426        5.118525
# 42     121.695625      2.215492        37.717642        1.243282
# 43     164.436143     13.525137        54.672633        2.591833
# 44     105.534198      6.246149        36.815907        2.118624
# 45     123.235140      6.654093        51.971642        1.662944
# 46     185.937336     28.483156        55.694827        3.891884
# 47     167.592090     11.278209        56.157009        3.725003
# 48     123.431845      5.713194        42.910632        1.145687
# 49     172.841627     18.586399        54.827658        2.586585
# 50     163.253760      2.390564        39.261879        1.112362
# 51     206.992844      4.457834        48.061934        1.978250
# 52      88.174008      5.937297        34.731977        2.062573
# 53     105.062055      0.634610        45.687032        1.303049
# 54      93.427172      5.038396        35.379044        2.167226
# 55     171.658267     12.908401        60.014632        2.174242
# 56     140.920517      1.938466        60.507289        4.470702
# 57     147.836807      3.955539        55.123674        3.137112
# 58     108.333294     21.876329        43.362431        1.366923
# 59     161.054170      4.171876        53.614226        2.235737
# 60     124.162739      8.978439        50.024498        4.183089
# 61     155.038323     14.105967        65.396910        2.703117
# 62     198.446677     11.645487        54.279347        1.904885
# 63     178.194515     15.444920        54.012173        1.509559
# 64     107.289603      6.871521        37.752408        1.741101
# 65     149.945519      3.667156        61.197640        4.611672
# 66     166.474794      8.240986        59.862654        3.653004
# 67     114.515565      9.050390        40.390271        3.260744
# 68     120.142652      2.547198        42.829119        3.086573
# 69      52.496580      1.789118        13.236319        0.225095
# 70     126.441910      4.213450        38.252515        2.459888
# 71     126.799191      6.381654        46.870050        2.499954
# 72     136.447393      7.922642        43.574614        2.174187
# 73      98.753178      8.417622        33.865508        1.514538
# 74     189.212244     10.226823        52.679646        1.119098
# 75     126.392198      2.379705        52.214323        1.485076
# 76     207.708015      5.867490        54.272706        2.607428
# 77     142.095158      3.192888        57.658476        2.225266
# 78     113.977181      1.309038        43.868954        2.230080
# 79      92.591322      0.962934        32.651992        2.293414
# 80     171.174327      9.741879        56.769563        3.344505
# 81     117.460737     11.854977        40.945752        2.983413
# 82     162.096730      5.265232        37.386040        1.193738
# 83     155.423620     10.595533        54.941430        2.717429
# 84     143.532129      9.473637        60.579884        5.666160
# 85     212.427284     13.041426        48.074371        3.758823
# 86     192.479275      7.588902        59.526867        3.599821
# 87     161.782233     12.558838        62.314604        2.137713
# 88     103.503729      7.488184        36.675332        2.588607
# 89     106.999169      8.609936        36.906986        1.991963
# 90     216.454513     12.340169        49.215487        3.259264
# 91     250.230540     12.582464        55.171705        5.404986
# 92     207.262632     15.340524        47.243107        4.362622
# 93     146.566832      5.320103        36.577174        1.753091
# 94     109.453928     11.445499        45.766297        1.626071
# 95     216.706130     11.818691        43.838762        3.841365
# 96     199.527039     12.917933        59.575144        2.820010
# 97     170.747486      9.714541        53.754470        1.141130
# 98     140.020603      1.744248        46.809857        1.852725
# 99     270.296991     13.258524        54.369833        1.777573
#
#    param_feature_fraction param_learning_rate param_min_child_samples  \
# 0                     0.4                0.05                     813
# 1                     0.6                0.01                     954
# 2                       1                0.01                     104
# 3                     0.4                0.01                     211
# 4                     0.7                0.01                     748
# 5                     0.9                0.05                     289
# 6                     0.5                0.05                     488
# 7                     0.9                 0.1                     224
# 8                     0.6                0.05                     634
# 9                     0.7                0.05                     801
# 10                    0.5                0.01                     456
# 11                    0.6                0.05                     820
# 12                    0.5                0.05                     650
# 13                    0.4                0.01                     404
# 14                      1                0.05                     651
# 15                    0.5                0.05                     850
# 16                    0.9                0.01                     534
# 17                    0.5                 0.1                     931
# 18                      1                 0.1                     873
# 19                    0.6                 0.1                     115
# 20                    0.6                 0.1                     543
# 21                      1                 0.1                     235
# 22                    0.4                 0.1                     388
# 23                    0.6                0.05                     940
# 24                    0.8                 0.1                     149
# 25                      1                 0.1                     773
# 26                    0.8                0.05                     698
# 27                    0.8                0.01                     777
# 28                      1                 0.1                     840
# 29                    0.9                0.01                     549
# 30                    0.7                 0.1                     469
# 31                    0.8                0.01                     479
# 32                    0.5                 0.1                     617
# 33                    0.5                0.05                     331
# 34                    0.7                 0.1                     713
# 35                    0.6                0.05                     504
# 36                    0.7                0.05                     321
# 37                      1                0.01                     951
# 38                    0.4                 0.1                     969
# 39                      1                0.01                     523
# 40                    0.9                 0.1                     926
# 41                    0.9                0.05                     553
# 42                    0.9                0.05                     738
# 43                    0.6                0.01                     745
# 44                    0.4                0.01                     345
# 45                    0.4                 0.1                     402
# 46                    0.7                0.05                     755
# 47                      1                 0.1                     250
# 48                    0.8                 0.1                     190
# 49                    0.7                0.05                     227
# 50                    0.9                0.01                     350
# 51                      1                0.01                     309
# 52                    0.5                 0.1                     388
# 53                    0.4                 0.1                     468
# 54                    0.4                0.01                     955
# 55                      1                 0.1                     515
# 56                    0.4                 0.1                     178
# 57                    0.8                 0.1                     372
# 58                    0.6                 0.1                     651
# 59                    0.6                0.01                     321
# 60                    0.4                0.05                     905
# 61                    0.5                0.05                     845
# 62                    0.7                0.01                     904
# 63                      1                0.05                     402
# 64                    0.9                 0.1                     189
# 65                    0.6                 0.1                     261
# 66                    0.9                 0.1                     543
# 67                    0.7                 0.1                     122
# 68                    0.7                 0.1                     468
# 69                      1                0.05                     713
# 70                    0.8                0.01                     909
# 71                    0.4                0.05                     826
# 72                    0.8                0.05                     141
# 73                    0.5                0.05                     549
# 74                    0.7                0.01                     997
# 75                    0.4                 0.1                     274
# 76                    0.8                0.01                     119
# 77                    0.4                 0.1                     778
# 78                    0.8                 0.1                     522
# 79                    0.4                0.01                     397
# 80                    0.5                0.01                     598
# 81                    0.5                0.01                     617
# 82                      1                0.01                     768
# 83                    0.5                0.01                     472
# 84                    0.4                 0.1                     856
# 85                    0.9                0.01                     748
# 86                    0.6                0.01                     827
# 87                    0.7                 0.1                     717
# 88                    0.7                 0.1                     570
# 89                    0.6                0.01                     723
# 90                      1                0.01                     787
# 91                      1                0.01                     352
# 92                    0.9                0.01                     991
# 93                    0.9                0.01                     226
# 94                    0.4                 0.1                     381
# 95                      1                0.01                     648
# 96                    0.8                0.05                     873
# 97                      1                 0.1                     237
# 98                    0.5                0.01                     899
# 99                    0.9                0.01                     286
#
#    param_num_leaves param_reg_alpha param_reg_lambda param_subsample  \
# 0               860               1                0             0.8
# 1                77               0                2               1
# 2               934               2                7             0.6
# 3               835              10                1             0.9
# 4               233               1              0.1             0.6
# 5              1020              10                2             0.9
# 6               143               2                1             0.6
# 7               885               1                0             0.6
# 8               256               1              0.1             0.8
# 9              1074               0                1             0.7
# 10              609               2               10             0.9
# 11              329               1                0             0.9
# 12              859              10                2             0.9
# 13              263             0.1                7               1
# 14              473              10              0.1               1
# 15             1210              10              0.1             0.9
# 16              573               0                2             0.9
# 17             1069               7                7               1
# 18              336              10               10             0.9
# 19             1038               1                0             0.7
# 20              118               7                7             0.6
# 21             1262               1                2             0.8
# 22              423               0                2             0.9
# 23              423               1                1             0.7
# 24              117               7                0               1
# 25              104               7                1             0.7
# 26              446              10              0.1               1
# 27              306               7                7             0.9
# 28              372              10                7             0.9
# 29               98              10                0               1
# 30              845               0               10             0.6
# 31              160               7                7             0.6
# 32              253               2                7             0.8
# 33              632               7               10             0.8
# 34              507             0.1               10             0.6
# 35              477               0                7             0.6
# 36              934              10                0             0.9
# 37             1206               0                1             0.7
# 38              953               0                1             0.8
# 39              771              10              0.1             0.7
# 40             1003              10                7               1
# 41             1092               0              0.1             0.7
# 42              298               7                0             0.6
# 43             1030               0              0.1             0.8
# 44              220               2                7             0.6
# 45              708               2                2             0.9
# 46             1027              10                1               1
# 47             1228               0                0             0.6
# 48              371               2                1               1
# 49              975               7               10             0.6
# 50              407             0.1               10               1
# 51              562               2                1             0.9
# 52              181               0                7               1
# 53              600              10                0             0.6
# 54              147              10               10             0.7
# 55             1214              10               10             0.6
# 56             1234             0.1                2               1
# 57              788             0.1                0             0.7
# 58              470              10                7               1
# 59              584               0              0.1             0.8
# 60              601              10                2             0.8
# 61             1128               2                7             0.9
# 62             1078               7                0             0.9
# 63              632             0.1                2             0.9
# 64              336               0                0               1
# 65             1015               1                2             0.9
# 66              896               1                2             0.8
# 67              293              10                2               1
# 68              337               2                0               1
# 69               12               7                1             0.8
# 70              201               1              0.1             0.6
# 71              454               7                7             0.6
# 72              328              10                1               1
# 73              155             0.1                0             0.6
# 74              791               2              0.1             0.7
# 75             1141               1                2             0.7
# 76             1242             0.1               10             0.8
# 77             1244              10                1             0.6
# 78              450               1                0             0.7
# 79               93               7                1               1
# 80             1208               0                7             0.8
# 81              286               1              0.1             0.8
# 82              354               1                7             0.6
# 83              873               2               10             0.8
# 84             1267             0.1              0.1             0.8
# 85              678              10               10             0.8
# 86             1173             0.1              0.1             0.9
# 87             1133              10               10               1
# 88              231               1              0.1               1
# 89              149               0                0             0.6
# 90              737             0.1               10             0.6
# 91             1062             0.1              0.1             0.9
# 92              629               1               10             0.9
# 93              265             0.1                1             0.6
# 94              448             0.1               10             0.9
# 95              489             0.1              0.1               1
# 96             1176              10                7             0.7
# 97              936             0.1              0.1             0.6
# 98              506               7              0.1             0.7
# 99             1218               2               10             0.8
#
#                                                params  split0_test_score  \
# 0   {'feature_fraction': 0.4, 'learning_rate': 0.0...          -0.401045
# 1   {'feature_fraction': 0.6, 'learning_rate': 0.0...          -0.509492
# 2   {'feature_fraction': 1, 'learning_rate': 0.01,...          -0.444789
# 3   {'feature_fraction': 0.4, 'learning_rate': 0.0...          -0.507739
# 4   {'feature_fraction': 0.7, 'learning_rate': 0.0...          -0.486628
# 5   {'feature_fraction': 0.9, 'learning_rate': 0.0...          -0.363841
# 6   {'feature_fraction': 0.5, 'learning_rate': 0.0...          -0.399425
# 7   {'feature_fraction': 0.9, 'learning_rate': 0.1...          -0.366024
# 8   {'feature_fraction': 0.6, 'learning_rate': 0.0...          -0.382126
# 9   {'feature_fraction': 0.7, 'learning_rate': 0.0...          -0.365669
# 10  {'feature_fraction': 0.5, 'learning_rate': 0.0...          -0.487579
# 11  {'feature_fraction': 0.6, 'learning_rate': 0.0...          -0.377648
# 12  {'feature_fraction': 0.5, 'learning_rate': 0.0...          -0.375178
# 13  {'feature_fraction': 0.4, 'learning_rate': 0.0...          -0.515474
# 14  {'feature_fraction': 1, 'learning_rate': 0.05,...          -0.366506
# 15  {'feature_fraction': 0.5, 'learning_rate': 0.0...          -0.372927
# 16  {'feature_fraction': 0.9, 'learning_rate': 0.0...          -0.456845
# 17  {'feature_fraction': 0.5, 'learning_rate': 0.1...          -0.366026
# 18  {'feature_fraction': 1, 'learning_rate': 0.1, ...          -0.369677
# 19  {'feature_fraction': 0.6, 'learning_rate': 0.1...          -0.365268
# 20  {'feature_fraction': 0.6, 'learning_rate': 0.1...          -0.372329
# 21  {'feature_fraction': 1, 'learning_rate': 0.1, ...          -0.366797
# 22  {'feature_fraction': 0.4, 'learning_rate': 0.1...          -0.378194
# 23  {'feature_fraction': 0.6, 'learning_rate': 0.0...          -0.374748
# 24  {'feature_fraction': 0.8, 'learning_rate': 0.1...          -0.369286
# 25  {'feature_fraction': 1, 'learning_rate': 0.1, ...          -0.371434
# 26  {'feature_fraction': 0.8, 'learning_rate': 0.0...          -0.367517
# 27  {'feature_fraction': 0.8, 'learning_rate': 0.0...          -0.474375
# 28  {'feature_fraction': 1, 'learning_rate': 0.1, ...          -0.368587
# 29  {'feature_fraction': 0.9, 'learning_rate': 0.0...          -0.497173
# 30  {'feature_fraction': 0.7, 'learning_rate': 0.1...          -0.365215
# 31  {'feature_fraction': 0.8, 'learning_rate': 0.0...          -0.488530
# 32  {'feature_fraction': 0.5, 'learning_rate': 0.1...          -0.369028
# 33  {'feature_fraction': 0.5, 'learning_rate': 0.0...          -0.377724
# 34  {'feature_fraction': 0.7, 'learning_rate': 0.1...          -0.365674
# 35  {'feature_fraction': 0.6, 'learning_rate': 0.0...          -0.373211
# 36  {'feature_fraction': 0.7, 'learning_rate': 0.0...          -0.365882
# 37  {'feature_fraction': 1, 'learning_rate': 0.01,...          -0.440450
# 38  {'feature_fraction': 0.4, 'learning_rate': 0.1...          -0.375239
# 39  {'feature_fraction': 1, 'learning_rate': 0.01,...          -0.447659
# 40  {'feature_fraction': 0.9, 'learning_rate': 0.1...          -0.366428
# 41  {'feature_fraction': 0.9, 'learning_rate': 0.0...          -0.363743
# 42  {'feature_fraction': 0.9, 'learning_rate': 0.0...          -0.369238
# 43  {'feature_fraction': 0.6, 'learning_rate': 0.0...          -0.473066
# 44  {'feature_fraction': 0.4, 'learning_rate': 0.0...          -0.516821
# 45  {'feature_fraction': 0.4, 'learning_rate': 0.1...          -0.375961
# 46  {'feature_fraction': 0.7, 'learning_rate': 0.0...          -0.366069
# 47  {'feature_fraction': 1, 'learning_rate': 0.1, ...          -0.366676
# 48  {'feature_fraction': 0.8, 'learning_rate': 0.1...          -0.365982
# 49  {'feature_fraction': 0.7, 'learning_rate': 0.0...          -0.366178
# 50  {'feature_fraction': 0.9, 'learning_rate': 0.0...          -0.463221
# 51  {'feature_fraction': 1, 'learning_rate': 0.01,...          -0.454551
# 52  {'feature_fraction': 0.5, 'learning_rate': 0.1...          -0.370089
# 53  {'feature_fraction': 0.4, 'learning_rate': 0.1...          -0.376832
# 54  {'feature_fraction': 0.4, 'learning_rate': 0.0...          -0.520136
# 55  {'feature_fraction': 1, 'learning_rate': 0.1, ...          -0.366585
# 56  {'feature_fraction': 0.4, 'learning_rate': 0.1...          -0.374346
# 57  {'feature_fraction': 0.8, 'learning_rate': 0.1...          -0.365194
# 58  {'feature_fraction': 0.6, 'learning_rate': 0.1...          -0.365610
# 59  {'feature_fraction': 0.6, 'learning_rate': 0.0...          -0.479068
# 60  {'feature_fraction': 0.4, 'learning_rate': 0.0...          -0.404821
# 61  {'feature_fraction': 0.5, 'learning_rate': 0.0...          -0.373415
# 62  {'feature_fraction': 0.7, 'learning_rate': 0.0...          -0.464811
# 63  {'feature_fraction': 1, 'learning_rate': 0.05,...          -0.365847
# 64  {'feature_fraction': 0.9, 'learning_rate': 0.1...          -0.367788
# 65  {'feature_fraction': 0.6, 'learning_rate': 0.1...          -0.364583
# 66  {'feature_fraction': 0.9, 'learning_rate': 0.1...          -0.366365
# 67  {'feature_fraction': 0.7, 'learning_rate': 0.1...          -0.366196
# 68  {'feature_fraction': 0.7, 'learning_rate': 0.1...          -0.365743
# 69  {'feature_fraction': 1, 'learning_rate': 0.05,...          -0.461524
# 70  {'feature_fraction': 0.8, 'learning_rate': 0.0...          -0.483919
# 71  {'feature_fraction': 0.4, 'learning_rate': 0.0...          -0.407712
# 72  {'feature_fraction': 0.8, 'learning_rate': 0.0...          -0.369761
# 73  {'feature_fraction': 0.5, 'learning_rate': 0.0...          -0.397759
# 74  {'feature_fraction': 0.7, 'learning_rate': 0.0...          -0.468030
# 75  {'feature_fraction': 0.4, 'learning_rate': 0.1...          -0.374362
# 76  {'feature_fraction': 0.8, 'learning_rate': 0.0...          -0.452311
# 77  {'feature_fraction': 0.4, 'learning_rate': 0.1...          -0.374256
# 78  {'feature_fraction': 0.8, 'learning_rate': 0.1...          -0.366047
# 79  {'feature_fraction': 0.4, 'learning_rate': 0.0...          -0.523459
# 80  {'feature_fraction': 0.5, 'learning_rate': 0.0...          -0.481798
# 81  {'feature_fraction': 0.5, 'learning_rate': 0.0...          -0.496594
# 82  {'feature_fraction': 1, 'learning_rate': 0.01,...          -0.463940
# 83  {'feature_fraction': 0.5, 'learning_rate': 0.0...          -0.484243
# 84  {'feature_fraction': 0.4, 'learning_rate': 0.1...          -0.374663
# 85  {'feature_fraction': 0.9, 'learning_rate': 0.0...          -0.453299
# 86  {'feature_fraction': 0.6, 'learning_rate': 0.0...          -0.472112
# 87  {'feature_fraction': 0.7, 'learning_rate': 0.1...          -0.365004
# 88  {'feature_fraction': 0.7, 'learning_rate': 0.1...          -0.367264
# 89  {'feature_fraction': 0.6, 'learning_rate': 0.0...          -0.499472
# 90  {'feature_fraction': 1, 'learning_rate': 0.01,...          -0.449053
# 91  {'feature_fraction': 1, 'learning_rate': 0.01,...          -0.442437
# 92  {'feature_fraction': 0.9, 'learning_rate': 0.0...          -0.454808
# 93  {'feature_fraction': 0.9, 'learning_rate': 0.0...          -0.472194
# 94  {'feature_fraction': 0.4, 'learning_rate': 0.1...          -0.378026
# 95  {'feature_fraction': 1, 'learning_rate': 0.01,...          -0.457470
# 96  {'feature_fraction': 0.8, 'learning_rate': 0.0...          -0.363737
# 97  {'feature_fraction': 1, 'learning_rate': 0.1, ...          -0.367100
# 98  {'feature_fraction': 0.5, 'learning_rate': 0.0...          -0.489551
# 99  {'feature_fraction': 0.9, 'learning_rate': 0.0...          -0.444105
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0           -0.388379          -0.393592        -0.394338        0.005198
# 1           -0.484588          -0.494892        -0.496324        0.010218
# 2           -0.427840          -0.435850        -0.436160        0.006923
# 3           -0.486700          -0.496028        -0.496822        0.008607
# 4           -0.465884          -0.475263        -0.475925        0.008482
# 5           -0.340956          -0.366650        -0.357149        0.011507
# 6           -0.380525          -0.384536        -0.388162        0.008131
# 7           -0.338947          -0.369856        -0.358276        0.013756
# 8           -0.364786          -0.375064        -0.373992        0.007120
# 9           -0.346112          -0.367443        -0.359741        0.009665
# 10          -0.468610          -0.477673        -0.477954        0.007747
# 11          -0.361964          -0.373149        -0.370920        0.006594
# 12          -0.360086          -0.373160        -0.369475        0.006689
# 13          -0.493653          -0.503143        -0.504090        0.008933
# 14          -0.348905          -0.367941        -0.361117        0.008655
# 15          -0.358226          -0.372662        -0.367938        0.006869
# 16          -0.437162          -0.446001        -0.446670        0.008049
# 17          -0.344926          -0.368960        -0.359971        0.010706
# 18          -0.345022          -0.370529        -0.361743        0.011829
# 19          -0.340193          -0.368432        -0.357965        0.012632
# 20          -0.356957          -0.370435        -0.366574        0.006844
# 21          -0.338961          -0.369865        -0.358541        0.013902
# 22          -0.367086          -0.375809        -0.373696        0.004775
# 23          -0.358394          -0.371818        -0.368320        0.007120
# 24          -0.353232          -0.370576        -0.364365        0.007889
# 25          -0.352329          -0.371631        -0.365131        0.009053
# 26          -0.348750          -0.367789        -0.361352        0.008912
# 27          -0.454493          -0.463817        -0.464228        0.008122
# 28          -0.345151          -0.370708        -0.361482        0.011580
# 29          -0.470310          -0.478984        -0.482156        0.011194
# 30          -0.341276          -0.368823        -0.358438        0.012225
# 31          -0.465228          -0.474403        -0.476054        0.009585
# 32          -0.352302          -0.369410        -0.363580        0.007976
# 33          -0.362670          -0.374255        -0.371550        0.006437
# 34          -0.343918          -0.369087        -0.359560        0.011148
# 35          -0.357316          -0.371328        -0.367285        0.007091
# 36          -0.347017          -0.367606        -0.360168        0.009326
# 37          -0.424379          -0.433256        -0.432695        0.006573
# 38          -0.360429          -0.373678        -0.369782        0.006644
# 39          -0.430310          -0.438450        -0.438807        0.007087
# 40          -0.339271          -0.369611        -0.358436        0.013614
# 41          -0.340347          -0.366433        -0.356841        0.011715
# 42          -0.352061          -0.368199        -0.363166        0.007864
# 43          -0.454116          -0.463818        -0.463667        0.007737
# 44          -0.494799          -0.504326        -0.505315        0.009018
# 45          -0.362289          -0.374646        -0.370965        0.006158
# 46          -0.346605          -0.367675        -0.360116        0.009576
# 47          -0.338969          -0.370052        -0.358566        0.013925
# 48          -0.343967          -0.368930        -0.359626        0.011138
# 49          -0.346991          -0.367553        -0.360241        0.009386
# 50          -0.443219          -0.452109        -0.452850        0.008183
# 51          -0.435788          -0.444307        -0.444882        0.007671
# 52          -0.354286          -0.369802        -0.364725        0.007383
# 53          -0.364265          -0.375049        -0.372049        0.005552
# 54          -0.497302          -0.507029        -0.508156        0.009356
# 55          -0.339261          -0.370468        -0.358771        0.013887
# 56          -0.357123          -0.374093        -0.368521        0.008060
# 57          -0.339538          -0.369729        -0.358154        0.013293
# 58          -0.345654          -0.368609        -0.359957        0.010188
# 59          -0.459861          -0.469514        -0.469481        0.007841
# 60          -0.392140          -0.395401        -0.397454        0.005377
# 61          -0.358020          -0.372568        -0.368001        0.007066
# 62          -0.446579          -0.456184        -0.455858        0.007447
# 63          -0.344998          -0.367460        -0.359435        0.010230
# 64          -0.345207          -0.370009        -0.361001        0.011205
# 65          -0.341839          -0.369190        -0.358537        0.011956
# 66          -0.338819          -0.369766        -0.358316        0.013857
# 67          -0.345827          -0.368504        -0.360176        0.010190
# 68          -0.345891          -0.368775        -0.360136        0.010149
# 69          -0.439207          -0.436515        -0.445749        0.011209
# 70          -0.461587          -0.471511        -0.472339        0.009136
# 71          -0.394420          -0.397584        -0.399905        0.005670
# 72          -0.352428          -0.368912        -0.363700        0.007978
# 73          -0.379437          -0.384591        -0.387262        0.007715
# 74          -0.449797          -0.459208        -0.459012        0.007445
# 75          -0.358093          -0.373702        -0.368719        0.007519
# 76          -0.434302          -0.444356        -0.443656        0.007369
# 77          -0.359248          -0.373777        -0.369094        0.006965
# 78          -0.342901          -0.369571        -0.359506        0.011830
# 79          -0.500212          -0.510262        -0.511311        0.009520
# 80          -0.462796          -0.472115        -0.472236        0.007758
# 81          -0.476502          -0.486148        -0.486415        0.008205
# 82          -0.444260          -0.452615        -0.453605        0.008065
# 83          -0.465228          -0.474432        -0.474634        0.007764
# 84          -0.359030          -0.373758        -0.369150        0.007166
# 85          -0.434275          -0.443598        -0.443724        0.007767
# 86          -0.453135          -0.462813        -0.462687        0.007748
# 87          -0.341906          -0.369268        -0.358726        0.012020
# 88          -0.348284          -0.370000        -0.361850        0.009657
# 89          -0.476423          -0.486373        -0.487423        0.009439
# 90          -0.431462          -0.439412        -0.439975        0.007193
# 91          -0.425600          -0.434165        -0.434068        0.006874
# 92          -0.435809          -0.444699        -0.445105        0.007762
# 93          -0.451168          -0.460847        -0.461403        0.008593
# 94          -0.366150          -0.375900        -0.373359        0.005171
# 95          -0.438647          -0.446667        -0.447595        0.007713
# 96          -0.341412          -0.366521        -0.357223        0.011238
# 97          -0.340074          -0.370074        -0.359083        0.013496
# 98          -0.470317          -0.479663        -0.479844        0.007853
# 99          -0.426604          -0.436340        -0.435683        0.007160
#
#     rank_test_score
# 0                60
# 1                95
# 2                66
# 3                96
# 4                88
# 5                 2
# 6                59
# 7                 6
# 8                57
# 9                20
# 10               90
# 11               51
# 12               49
# 13               97
# 14               29
# 15               42
# 16               74
# 17               22
# 18               32
# 19                4
# 20               40
# 21               11
# 22               56
# 23               44
# 24               37
# 25               39
# 26               30
# 27               83
# 28               31
# 29               92
# 30                9
# 31               89
# 32               35
# 33               53
# 34               18
# 35               41
# 36               25
# 37               63
# 38               50
# 39               67
# 40                8
# 41                1
# 42               34
# 43               82
# 44               98
# 45               52
# 46               23
# 47               12
# 48               19
# 49               27
# 50               76
# 51               71
# 52               38
# 53               54
# 54               99
# 55               14
# 56               45
# 57                5
# 58               21
# 59               84
# 60               61
# 61               43
# 62               78
# 63               16
# 64               28
# 65               10
# 66                7
# 67               26
# 68               24
# 69               73
# 70               86
# 71               62
# 72               36
# 73               58
# 74               79
# 75               46
# 76               69
# 77               47
# 78               17
# 79              100
# 80               85
# 81               93
# 82               77
# 83               87
# 84               48
# 85               70
# 86               81
# 87               13
# 88               33
# 89               94
# 90               68
# 91               64
# 92               72
# 93               80
# 94               55
# 95               75
# 96                3
# 97               15
# 98               91
# 99               65

# %%
gs.best_score_
# Out:
# -0.35684080701187665

# %%
test_df = import_data('test.csv')
building_df = import_data('building_metadata.csv')
weather_df = import_data('weather_test.csv')
# Out:
# Memory usage of dataframe is 1272.51 MB
# Memory usage after optimization is: 358.65 MB
# Decreased by 71.8%
# Memory usage of dataframe is 0.07 MB
# Memory usage after optimization is: 0.02 MB
# Decreased by 73.8%
# Memory usage of dataframe is 19.04 MB
# Memory usage after optimization is: 5.25 MB
# Decreased by 72.4%

# %%
#test_df = test_df [ test_df['building_id'] != 1099 ]
test_df['timestamp'] = pd.to_datetime(test_df['timestamp'])
#test_df = test_df.query('not (building_id <= 104 & meter == 0 & timestamp <= "2016-05-20")')

# %%
weather_df = fill_weather_dataset(weather_df)

percip = weather_df.groupby(['site_id','month'])[['precip_depth_1_hr']].mean()
cloud = weather_df.groupby(['site_id','month'])[['cloud_coverage']].mean()
airtemp = weather_df.groupby(['site_id','month'])[['air_temperature']].mean()
dewtemp = weather_df.groupby(['site_id','month'])[['dew_temperature']].mean()
sealevelp = weather_df.groupby(['site_id','month'])[['sea_level_pressure']].mean()
windd = weather_df.groupby(['site_id','month'])[['wind_direction']].mean()
winds = weather_df.groupby(['site_id','month'])[['wind_speed']].mean()

# %%
pd.set_option('display.max_rows', None)
# percip
# cloud
# airtemp
# dewtemp
# sealevelp
# windd
# winds
# Out:
#                precip_depth_1_hr
# site_id month
# 0       1               0.654297
#         2               0.229858
#         3               0.134399
#         4               0.354004
#         5               1.537109
#         6               2.132812
#         7               2.560547
#         8               1.849609
#         9               2.218750
#         10              0.784668
#         11              0.384766
#         12              1.110352
# 1       1                    NaN
#         2                    NaN
#         3                    NaN
#         4                    NaN
#         5                    NaN
#         6                    NaN
#         7                    NaN
#         8                    NaN
#         9                    NaN
#         10                   NaN
#         11                   NaN
#         12                   NaN
# 2       1               0.205933
#         2               0.282715
#         3               0.012123
#         4              -0.000694
#         5              -0.002016
#         6              -0.005554
#         7               0.149170
#         8               0.321289
#         9               0.049652
#         10              0.720215
#         11              0.060425
#         12              0.051758
# 3       1               0.422119
#         2               0.679688
#         3               0.752441
#         4               0.634277
#         5               1.806641
#         6               0.932129
#         7               1.652344
#         8               0.782227
#         9               1.506836
#         10              0.686035
#         11              1.402344
#         12              0.699707
# 4       1               1.860352
#         2               1.285156
#         3               1.022461
#         4               0.937988
#         5              -0.020981
#         6              -0.006428
#         7              -0.008186
#         8              -0.023422
#         9               0.008530
#         10              0.020340
#         11              0.897949
#         12              0.294434
# 5       1                    NaN
#         2                    NaN
#         3                    NaN
#         4                    NaN
#         5                    NaN
#         6                    NaN
#         7                    NaN
#         8                    NaN
#         9                    NaN
#         10                   NaN
#         11                   NaN
#         12                   NaN
# 6       1               0.574219
#         2               0.618652
#         3               0.542480
#         4               0.972168
#         5               2.501953
#         6               1.872070
#         7               1.157227
#         8               1.266602
#         9               1.136719
#         10              1.063477
#         11              1.148438
#         12              0.875000
# 7       1               6.519531
#         2               6.277344
#         3               5.675781
#         4              11.218750
#         5              14.500000
#         6              17.531250
#         7              31.671875
#         8              26.609375
#         9              14.234375
#         10             14.945312
#         11              7.640625
#         12              7.179688
# 8       1               0.654297
#         2               0.229858
#         3               0.134399
#         4               0.354004
#         5               1.537109
#         6               2.132812
#         7               2.560547
#         8               1.849609
#         9               2.218750
#         10              0.784668
#         11              0.384766
#         12              1.110352
# 9       1               0.467285
#         2               0.491455
#         3               0.591309
#         4               0.223755
#         5               0.614746
#         6               0.776367
#         7               0.473389
#         8               1.446289
#         9               1.495117
#         10              1.202148
#         11              0.258057
#         12              1.365234
# 10      1               0.500000
#         2               0.339600
#         3               0.564453
#         4               0.614258
#         5               0.231812
#         6               0.136108
#         7               0.002687
#         8               0.033203
#         9               0.259766
#         10              0.414551
#         11              0.456299
#         12              0.066650
# 11      1               6.519531
#         2               6.277344
#         3               5.675781
#         4              11.218750
#         5              14.500000
#         6              17.531250
#         7              31.671875
#         8              26.609375
#         9              14.234375
#         10             14.945312
#         11              7.640625
#         12              7.179688
# 12      1                    NaN
#         2                    NaN
#         3                    NaN
#         4                    NaN
#         5                    NaN
#         6                    NaN
#         7                    NaN
#         8                    NaN
#         9                    NaN
#         10                   NaN
#         11                   NaN
#         12                   NaN
# 13      1               0.283203
#         2               0.271240
#         3               0.224487
#         4               0.810059
#         5               1.290039
#         6               1.242188
#         7               1.075195
#         8               1.174805
#         9               1.190430
#         10              0.979004
#         11              0.201416
#         12              0.343750
# 14      1               0.671875
#         2               0.984863
#         3               0.931641
#         4               0.836914
#         5               1.959961
#         6               1.311523
#         7               1.586914
#         8               0.958984
#         9               1.236328
#         10              1.291016
#         11              1.474609
#         12              0.883301
# 15      1               0.811523
#         2               0.905273
#         3               1.529297
#         4               3.300781
#         5               5.339844
#         6               5.109375
#         7              13.273438
#         8               6.304688
#         9               8.023438
#         10              7.335938
#         11              2.078125
#         12              0.342773

# %%
for i in range(12):
    percip.loc[(1,i+1)] = percip.loc[(7,i+1)]
    percip.loc[(5,i+1)] = percip.loc[(7,i+1)]
    percip.loc[(12,i+1)] = percip.loc[(7,i+1)]
    
    cloud.loc[(7,i+1)] = cloud.loc[(5,i+1)]
    cloud.loc[(11,i+1)] = cloud.loc[(5,i+1)]
    
    sealevelp.loc[(5,i+1)] = sealevelp.loc[(7,i+1)]

# %%
weather_info = percip.join(cloud)
weather_info = weather_info.join(airtemp)
weather_info = weather_info.join(dewtemp)
weather_info = weather_info.join(sealevelp)
weather_info = weather_info.join(windd)
weather_info = weather_info.join(winds)
weather_info.head()
# Out:
#                precip_depth_1_hr  cloud_coverage  air_temperature  \
# site_id month
# 0       1               0.654297        2.929688        15.968750
#         2               0.229858        2.623047        20.562500
#         3               0.134399        2.160156        19.296875
#         4               0.354004        2.589844        22.859375
#         5               1.537109        3.021484        24.390625
#
#                dew_temperature  sea_level_pressure  wind_direction  wind_speed
# site_id month
# 0       1            10.429688              1021.5         182.375    3.982422
#         2            14.945312              1021.0         145.125    3.306641
#         3            10.070312              1020.0         171.750    3.962891
#         4            15.226562              1017.0         152.250    4.082031
#         5            18.781250              1016.0         145.625    3.808594

# %%
weather_df.update(weather_info,overwrite=False)
weather_df = weather_df.reset_index()
weather_df = weather_df.drop(['datetime','day','week','month'],axis=1)
weather_df.head()
# Out:
#    site_id            timestamp  air_temperature  cloud_coverage  \
# 0        0  2017-01-01 00:00:00        17.796875             4.0
# 1        0  2017-01-01 01:00:00        17.796875             2.0
# 2        0  2017-01-01 02:00:00        16.093750             0.0
# 3        0  2017-01-01 03:00:00        17.203125             0.0
# 4        0  2017-01-01 04:00:00        16.703125             2.0
#
#    dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  \
# 0        11.703125           0.654297              1021.5           100.0
# 1        12.796875           0.000000              1022.0           130.0
# 2        12.796875           0.000000              1022.0           140.0
# 3        13.296875           0.000000              1022.0           140.0
# 4        13.296875           0.000000              1022.5           130.0
#
#    wind_speed
# 0    3.599609
# 1    3.099609
# 2    3.099609
# 3    3.099609
# 4    2.599609

# %%
weather_df = get_meteorological_features(weather_df)
weather_df.head()
# Out:
#    site_id            timestamp  air_temperature  cloud_coverage  \
# 0        0  2017-01-01 00:00:00        17.796875             4.0
# 1        0  2017-01-01 01:00:00        17.796875             2.0
# 2        0  2017-01-01 02:00:00        16.093750             0.0
# 3        0  2017-01-01 03:00:00        17.203125             0.0
# 4        0  2017-01-01 04:00:00        16.703125             2.0
#
#    dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  \
# 0        11.703125           0.654297              1021.5           100.0
# 1        12.796875           0.000000              1022.0           130.0
# 2        12.796875           0.000000              1022.0           140.0
# 3        13.296875           0.000000              1022.0           140.0
# 4        13.296875           0.000000              1022.5           130.0
#
#    wind_speed  relative_humidity  feels_like
# 0    3.599609            67.4375   64.034375
# 1    3.099609            72.5625   64.034375
# 2    3.099609            80.7500   60.968750
# 3    3.099609            77.8750   62.965625
# 4    2.599609            80.3125   62.065625

# %%
weather_df['timestamp'] = pd.to_datetime(weather_df['timestamp'], format="%Y-%m-%d %H:%M:%S")

# merge data
test_df = test_df.merge(building_df, left_on='building_id',right_on='building_id',how='left')
test_df = test_df.merge(weather_df,how='left',left_on=['site_id','timestamp'],right_on=['site_id','timestamp'])
del weather_df
gc.collect()
# Out:
# 76

# %%
# feature engineering
test_df = features_engineering(test_df)

# transform target variable
test_df['square_feet'] = np.log1p(test_df["square_feet"])

test_df = test_df.drop(['month'], axis=1)
test_df = test_df.drop(['sea_level_pressure','wind_direction','wind_speed','year_built','floor_count'], axis=1)
test_df.head()
# Out:
#    row_id  building_id  meter  site_id  primary_use  square_feet  \
# 0       0            0      0        0            0     2.293916
# 1       1            1      0        0            0     2.187034
# 2       2            2      0        0            0     2.260709
# 3       3            3      0        0            0     2.404477
# 4       4            4      0        0            0     2.538966
#
#    air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  \
# 0        17.796875             4.0        11.703125           0.654297
# 1        17.796875             4.0        11.703125           0.654297
# 2        17.796875             4.0        11.703125           0.654297
# 3        17.796875             4.0        11.703125           0.654297
# 4        17.796875             4.0        11.703125           0.654297
#
#    relative_humidity  feels_like  hour  dayofweek
# 0            67.4375   64.034375     0          6
# 1            67.4375   64.034375     0          6
# 2            67.4375   64.034375     0          6
# 3            67.4375   64.034375     0          6
# 4            67.4375   64.034375     0          6

# %%
#{'feature_fraction': 1, 
# 'learning_rate': 0.1, 
# 'min_child_samples': 250, 
# 'num_leaves': 1228, 
# 'reg_alpha': 0, 
# 'reg_lambda': 0, 
# 'subsample': 0.6}

# THIS -RMLSE
#{'feature_fraction': 0.9, 
# 'learning_rate': 0.05, 
# 'min_child_samples': 553, 
# 'num_leaves': 1092, 'reg_alpha': 0, 
# 'reg_lambda': 0.1, 'subsample': 0.7}

# %%
categorical_features = ["building_id", "site_id", "meter", "primary_use",'dayofweek','hour']


lgb_train = lgb.Dataset(X_train, y_train, categorical_feature = categorical_features)

params = {
    
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': "rmlse",
    'feature_fraction': 0.9,
    'learning_rate': 0.05,
    'min_child_samples': 553,
    'num_leaves': 1092,
    'reg_alpha': 0,
    'reg_lambda': 0.1,
    'subsample': 0.7
}

gbm = lgb.train(params, lgb_train)
# Out:
# C:\Users\legle\Anaconda3\lib\site-packages\lightgbm\basic.py:1291: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')

# %%
categorical_features = ["building_id", "site_id", "meter", "primary_use",'dayofweek','hour']


gbm = lgb.LGBMRegressor(boosting_type='gbdt',
                       subsample=0.7,
                       learning_rate=0.05,
                       min_child_samples=553,
                       num_leaves=1092,
                       reg_alpha=0,
                       reg_lambda=0.1,
                       colsample_bytree=0.9,
                       random_state=314)

# THIS -RMLSE
#{'feature_fraction': 0.9, 
# 'learning_rate': 0.05, 
# 'min_child_samples': 553, 
# 'num_leaves': 1092, 'reg_alpha': 0, 
# 'reg_lambda': 0.1, 'subsample': 0.7}


gbm.fit(X_train, y_train, categorical_feature=categorical_features)
# Out:
# C:\Users\legle\Anaconda3\lib\site-packages\lightgbm\basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['building_id', 'dayofweek', 'hour', 'meter', 'primary_use', 'site_id']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=0.9,
#               importance_type='split', learning_rate=0.05, max_depth=-1,
#               min_child_samples=553, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=100, n_jobs=-1, num_leaves=1092, objective=None,
#               random_state=314, reg_alpha=0, reg_lambda=0.1, silent=True,
#               subsample=0.7, subsample_for_bin=200000, subsample_freq=0)

# %%
X_test.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-c8ff277ea5c9> in <module>
# ----> 1 X_test.head()
#
# NameError: name 'X_test' is not defined

# %%
X_test = test_df.drop(['row_id'],axis=1)
gbm_results = np.expm1(gbm.predict(X_test))

len(gbm_results)
# Out:
# 41697600

# %%
row_ids = test_df['row_id']

results_df = pd.DataFrame({"row_id": row_ids, "meter_reading":gbm_results})
results_df.head()
# Out:
#    row_id  meter_reading
# 0       0     188.450306
# 1       1      96.434727
# 2       2       8.194458
# 3       3     304.300250
# 4       4    1399.047062

# %%
results_df.to_csv('results_df_rmsle_.csv',index=False)
results.to_csv('rsCV_result_rmsle_.csv',index=False)
